# %% [markdown]
# ## Translation approach with keras
# following: https://towardsdatascience.com/neural-machine-translation-15ecf6b0b

# %%
import unicodedata
import re
import math
import psutil
import time
import datetime
from io import open
import random
from random import shuffle
import argparse
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.cuda

"""this line clears sys to allow for argparse to work as gradient clipper"""
import sys; sys.argv=['']; del sys

# %%
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# False

# %%
"""This function converts a Unicode string to plain ASCII 
from https://stackoverflow.com/a/518232/2809427"""
def uniToAscii(sentence):
    return ''.join(
        c for c in unicodedata.normalize('NFD', sentence)
        if unicodedata.category(c) != 'Mn'
    )


"""Lowercase, trim, and remove non-letter characters (from pytorch)"""
def normalizeString(s):
    s = re.sub(r" ##AT##-##AT## ", r" ", s)
    s = uniToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s   

  
"""Denote patterns that sentences must start with to be kept in dataset. 
Can be changed if desired (from pytorch)"""
eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)



"""Filters each input-output pair, keeping sentences that are less than max_length 
if start_filter is true, also filters out sentences that don't start with eng_prefixes"""
def filterPair(p, max_length, start_filter):
    filtered = len(p[0].split(' ')) < max_length and \
        len(p[1].split(' ')) < max_length 
    if start_filter:
        return filtered and p[1].startswith(eng_prefixes)
    else:
        return filtered

"""Filters all of the input-output language pairs in the dataset using filterPair 
for each pair (from pytorch)"""
def filterPairs(pairs, max_length, start_filter):
    return [pair for pair in pairs if filterPair(pair, max_length, start_filter)]

# %%
"""start of sentence tag"""
SOS_token = 0

"""end of sentence tag"""
EOS_token = 1

"""unknown word tag (this is used to handle words that are not in our Vocabulary)"""
UNK_token = 2


"""Lang class, used to store the vocabulary of each language"""
class Lang:
    def __init__(self, language):
        self.language_name = language
        self.word_to_index = {"SOS":SOS_token, "EOS":EOS_token, "<UNK>":UNK_token}
        self.word_to_count = {}
        self.index_to_word = {SOS_token: "SOS", EOS_token: "EOS", UNK_token: "<UNK>"}
        self.vocab_size = 3
        self.cutoff_point = -1


    def countSentence(self, sentence):
        for word in sentence.split(' '):
            self.countWords(word)

    """counts the number of times each word appears in the dataset"""
    def countWords(self, word):
        if word not in self.word_to_count:
            self.word_to_count[word] = 1
        else:
            self.word_to_count[word] += 1

    """if the number of unique words in the dataset is larger than the
    specified max_vocab_size, creates a cutoff point that is used to
    leave infrequent words out of the vocabulary"""
    def createCutoff(self, max_vocab_size):
        word_freqs = list(self.word_to_count.values())
        word_freqs.sort(reverse=True)
        if len(word_freqs) > max_vocab_size:
            self.cutoff_point = word_freqs[max_vocab_size]

    """assigns each unique word in a sentence a unique index"""
    def addSentence(self, sentence):
        new_sentence = ''
        for word in sentence.split(' '):
            unk_word = self.addWord(word)
            if not new_sentence:
                new_sentence =unk_word
            else:
                new_sentence = new_sentence + ' ' + unk_word
        return new_sentence

    """assigns a word a unique index if not already in vocabulary
    and it appeaars often enough in the dataset
    (self.word_to_count is larger than self.cutoff_point)"""
    def addWord(self, word):
        if self.word_to_count[word] > self.cutoff_point:
            if word not in self.word_to_index:
                self.word_to_index[word] = self.vocab_size
                self.index_to_word[self.vocab_size] = word
                self.vocab_size += 1
            return word
        else:
            return self.index_to_word[2]

# %%
'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').\
            read().strip().split('\n')

        lang2_lines = open(file_path[1], encoding='utf-8').\
            read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
            pairs.append([normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])])            


    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').\
        read().strip().split('\n')
        pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

'''prepares both the input and output Lang classes from the passed dataset'''

def prepareLangs(lang1, lang2, file_path, reverse=False):
    print("Reading lines...")

    if len(file_path) == 2:
        lang1_lines = open(file_path[0], encoding='utf-8').\
            read().strip().split('\n')

        lang2_lines = open(file_path[1], encoding='utf-8').\
            read().strip().split('\n')

        if len(lang1_lines) != len(lang2_lines):
            print("Input and output text sizes do not align")
            print("Number of lang1 lines: %s " %len(lang1_lines))
            print("Number of lang2 lines: %s " %len(lang2_lines))
            quit()

        pairs = []

        for line in range(len(lang1_lines)):
            pairs.append([normalizeString(lang1_lines[line]),
                          normalizeString(lang2_lines[line])])            


    elif len(file_path) == 1:
        lines = open(file_path[0], encoding='utf-8').\
        read().strip().split('\n')
        pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
"""completely prepares both input and output languages 
and returns cleaned and trimmed train and test pairs"""

def prepareData(lang1, lang2, file_path, max_vocab_size=50000, 
                reverse=False, trim=0, start_filter=False, perc_train_set=0.9, 
                print_to=None):
    
    input_lang, output_lang, pairs = prepareLangs(lang1, lang2, 
                                                  file_path, reverse)
    
    print("Read %s sentence pairs" % len(pairs))
    
    if print_to:
        with open(print_to,'a') as f:
            f.write("Read %s sentence pairs \n" % len(pairs))
    
    if trim != 0:
        pairs = filterPairs(pairs, trim, start_filter)
        print("Trimmed to %s sentence pairs" % len(pairs))
        if print_to:
            with open(print_to,'a') as f:
                f.write("Read %s sentence pairs \n" % len(pairs))

    print("Counting words...")
    for pair in pairs:
        input_lang.countSentence(pair[0])
        output_lang.countSentence(pair[1])


    input_lang.createCutoff(max_vocab_size)
    output_lang.createCutoff(max_vocab_size)

    pairs = [(input_lang.addSentence(pair[0]),output_lang.addSentence(pair[1])) 
             for pair in pairs]

    shuffle(pairs)
    
    train_pairs = pairs[:math.ceil(perc_train_set*len(pairs))]
    test_pairs = pairs[math.ceil(perc_train_set*len(pairs)):]

    print("Train pairs: %s" % (len(train_pairs)))
    print("Test pairs: %s" % (len(test_pairs)))
    print("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
    print("%s, %s -> %s" % (input_lang.language_name, len(input_lang.word_to_count),
                            input_lang.vocab_size,))
    print("%s, %s -> %s" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
    print()

    if print_to:
        with open(print_to,'a') as f:
            f.write("Train pairs: %s" % (len(train_pairs)))
            f.write("Test pairs: %s" % (len(test_pairs)))
            f.write("Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):")
            f.write("%s, %s -> %s" % (input_lang.language_name, 
                                      len(input_lang.word_to_count),
                                      input_lang.vocab_size,))
            f.write("%s, %s -> %s \n" % (output_lang.language_name, len(output_lang.word_to_count), 
                            output_lang.vocab_size))
        
    return input_lang, output_lang, train_pairs, test_pairs

# %%
"""converts a sentence to one hot encoding vectors - pytorch allows us to just
use the number corresponding to the unique index for that word,
rather than a complete one hot encoding vector for each word"""
def indexesFromSentence(lang, sentence):
    indexes = []
    for word in sentence.split(' '):
        try:
            indexes.append(lang.word_to_index[word])
        except:
            indexes.append(lang.word_to_index["<UNK>"])
    return indexes


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    result = torch.LongTensor(indexes).view(-1)
    if use_cuda:
        return result.cuda()
    else:
        return result
      
"""converts a pair of sentence (input and target) to a pair of tensors"""
def tensorsFromPair(input_lang, output_lang, pair):
    input_variable = tensorFromSentence(input_lang, pair[0])
    target_variable = tensorFromSentence(output_lang, pair[1])
    return (input_variable, target_variable)
  

"""converts from tensor of one hot encoding vector indices to sentence"""
def sentenceFromTensor(lang, tensor):
    raw = tensor.data
    words = []
    for num in raw:
        words.append(lang.index_to_word[num.item()])
    return ' '.join(words)

# %%
"""seperates data into batches of size batch_size"""
def batchify(data, input_lang, output_lang, batch_size, shuffle_data=True):
    if shuffle_data == True:
        shuffle(data)
    number_of_batches = len(data) // batch_size
    batches = list(range(number_of_batches))
    longest_elements = list(range(number_of_batches))
    
    for batch_number in range(number_of_batches):
        longest_input = 0
        longest_target = 0
        input_variables = list(range(batch_size))
        target_variables = list(range(batch_size))
        index = 0      
        for pair in range((batch_number*batch_size),((batch_number+1)*batch_size)):
            input_variables[index], target_variables[index] = tensorsFromPair(input_lang, output_lang, data[pair])
            if len(input_variables[index]) >= longest_input:
                longest_input = len(input_variables[index])
            if len(target_variables[index]) >= longest_target:
                longest_target = len(target_variables[index])
            index += 1
        batches[batch_number] = (input_variables, target_variables)
        longest_elements[batch_number] = (longest_input, longest_target)
    return batches , longest_elements, number_of_batches


"""pads batches to allow for sentences of variable lengths to be computed in parallel"""
def pad_batch(batch):
    padded_inputs = torch.nn.utils.rnn.pad_sequence(batch[0],padding_value=EOS_token)
    padded_targets = torch.nn.utils.rnn.pad_sequence(batch[1],padding_value=EOS_token)
    return (padded_inputs, padded_targets)

# %%
class EncoderRNN(nn.Module):
    def __init__(self,input_size,hidden_size,layers=1,dropout=0.1,
               bidirectional=True):
        super(EncoderRNN, self).__init__()

        if bidirectional:
            self.directions = 2
        else:
            self.directions = 1
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = layers
        self.dropout = dropout
        self.embedder = nn.Embedding(input_size,hidden_size)
        self.dropout = nn.Dropout(dropout)
        self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
        self.fc = nn.Linear(hidden_size*self.directions, hidden_size)

    def forward(self, input_data, h_hidden, c_hidden):
        embedded_data = self.embedder(input_data)
        embedded_data = self.dropout(embedded_data)
        hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))

        return hiddens, outputs

    """creates initial hidden states for encoder corresponding to batch size"""
    def create_init_hiddens(self, batch_size):
        h_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
        c_hidden = Variable(torch.zeros(self.num_layers*self.directions, 
                                    batch_size, self.hidden_size))
        if torch.cuda.is_available():
            return h_hidden.cuda(), c_hidden.cuda()
        else:
            return h_hidden, c_hidden

# %%
class DecoderAttn(nn.Module):
    def __init__(self, hidden_size, output_size, layers=1, dropout=0.1, bidirectional=True):
        super(DecoderAttn, self).__init__()

        if bidirectional:
            self.directions = 2
        else:
            self.directions = 1
        self.output_size = output_size
        self.hidden_size = hidden_size
        self.num_layers = layers
        self.dropout = dropout
        self.embedder = nn.Embedding(output_size,hidden_size)
        self.dropout = nn.Dropout(dropout)
        self.score_learner = nn.Linear(hidden_size*self.directions, 
                                   hidden_size*self.directions)
        self.lstm = nn.LSTM(input_size=hidden_size,hidden_size=hidden_size,
                        num_layers=layers,dropout=dropout,
                        bidirectional=bidirectional,batch_first=False)
        self.context_combiner = nn.Linear((hidden_size*self.directions)
                                      +(hidden_size*self.directions), hidden_size)
        self.tanh = nn.Tanh()
        self.output = nn.Linear(hidden_size, output_size)
        self.soft = nn.Softmax(dim=1)
        self.log_soft = nn.LogSoftmax(dim=1)


    def forward(self, input_data, h_hidden, c_hidden, encoder_hiddens):

        embedded_data = self.embedder(input_data)
        embedded_data = self.dropout(embedded_data)	
        batch_size = embedded_data.shape[1]
        hiddens, outputs = self.lstm(embedded_data, (h_hidden, c_hidden))	
        top_hidden = outputs[0].view(self.num_layers,self.directions,
                                 hiddens.shape[1],
                                 self.hidden_size)[self.num_layers-1]
        top_hidden = top_hidden.permute(1,2,0).contiguous().view(batch_size,-1, 1)

        prep_scores = self.score_learner(encoder_hiddens.permute(1,0,2))
        scores = torch.bmm(prep_scores, top_hidden)
        attn_scores = self.soft(scores)
        con_mat = torch.bmm(encoder_hiddens.permute(1,2,0),attn_scores)
        h_tilde = self.tanh(self.context_combiner(torch.cat((con_mat,
                                                         top_hidden),dim=1)
                                              .view(batch_size,-1)))
        pred = self.output(h_tilde)
        pred = self.log_soft(pred)

        return pred, outputs

# %%
'''Performs training on a single batch of training data. Computing the loss 
according to the passed loss_criterion and back-propagating on this loss.'''

def train_batch(input_batch, target_batch, encoder, decoder, 
                encoder_optimizer, decoder_optimizer, loss_criterion):
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    loss = 0
    enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

    enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

    decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
                    else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))

    dec_h_hidden = enc_outputs[0]
    dec_c_hidden = enc_outputs[1]

    for i in range(target_batch.shape[0]):
        pred, dec_outputs = decoder(decoder_input, dec_h_hidden, 
                                dec_c_hidden, enc_hiddens)

        decoder_input = target_batch[i].view(1,-1)
        dec_h_hidden = dec_outputs[0]
        dec_c_hidden = dec_outputs[1]

        loss += loss_criterion(pred,target_batch[i])


    loss.backward()

    torch.nn.utils.clip_grad_norm_(encoder.parameters(),args.clip)
    torch.nn.utils.clip_grad_norm_(decoder.parameters(),args.clip)

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_batch.shape[0]

# %%
'''Performs a complete epoch of training through all of the training_batches'''

def train(train_batches, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion):

    round_loss = 0
    i = 1
    for batch in train_batches:
        i += 1
        (input_batch, target_batch) = pad_batch(batch)
        batch_loss = train_batch(input_batch, target_batch, encoder, decoder, encoder_optimizer, decoder_optimizer, loss_criterion)
        round_loss += batch_loss

    return round_loss / len(train_batches)

# %%
'''Evaluates the loss on a single batch of test data. Computing the loss 
according to the passed loss_criterion. Does not perform back-prop'''

def test_batch(input_batch, target_batch, encoder, decoder, loss_criterion):

    loss = 0

    #create initial hidde state for encoder
    enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(input_batch.shape[1])

    enc_hiddens, enc_outputs = encoder(input_batch, enc_h_hidden, enc_c_hidden)

    decoder_input = Variable(torch.LongTensor(1,input_batch.shape[1]).
                           fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
                    else Variable(torch.LongTensor(1,input_batch.shape[1]).
                        fill_(output_lang.word_to_index.get("SOS")))
    dec_h_hidden = enc_outputs[0]
    dec_c_hidden = enc_outputs[1]

    for i in range(target_batch.shape[0]):
        pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

        topv, topi = pred.topk(1,dim=1)
        ni = topi.view(1,-1)

        decoder_input = ni
        dec_h_hidden = dec_outputs[0]
        dec_c_hidden = dec_outputs[1]

        loss += loss_criterion(pred,target_batch[i])

    return loss.item() / target_batch.shape[0]

# %%
'''Computes the loss value over all of the test_batches'''

def test(test_batches, encoder, decoder, loss_criterion):

    with torch.no_grad():
        test_loss = 0

        for batch in test_batches:
            (input_batch, target_batch) = pad_batch(batch)
            batch_loss = test_batch(input_batch, target_batch, encoder, decoder, loss_criterion)
            test_loss += batch_loss

    return test_loss / len(test_batches)

# %%
'''Returns the predicted translation of a given input sentence. Predicted
translation is trimmed to length of cutoff_length argument'''

def evaluate(encoder, decoder, sentence, cutoff_length):
    with torch.no_grad():
        input_variable = tensorFromSentence(input_lang, sentence)
        input_variable = input_variable.view(-1,1)
        enc_h_hidden, enc_c_hidden = encoder.create_init_hiddens(1)

        enc_hiddens, enc_outputs = encoder(input_variable, enc_h_hidden, enc_c_hidden)

        decoder_input = Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")).cuda()) if use_cuda \
                        else Variable(torch.LongTensor(1,1).fill_(output_lang.word_to_index.get("SOS")))
        dec_h_hidden = enc_outputs[0]
        dec_c_hidden = enc_outputs[1]

        decoded_words = []

        for di in range(cutoff_length):
            pred, dec_outputs = decoder(decoder_input, dec_h_hidden, dec_c_hidden, enc_hiddens)

            topv, topi = pred.topk(1,dim=1)
            ni = topi.item()
            if ni == output_lang.word_to_index.get("EOS"):
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index_to_word[ni])

            decoder_input = Variable(torch.LongTensor(1,1).fill_(ni).cuda()) if use_cuda \
                            else Variable(torch.LongTensor(1,1).fill_(ni))
            dec_h_hidden = dec_outputs[0]
            dec_c_hidden = dec_outputs[1]

        output_sentence = ' '.join(decoded_words)

        return output_sentence

# %%
'''Evaluates prediction translations for a specified number (n) of sentences
chosen randomly from a list of passed sentence pairs. Returns three sentences
in the format:
                  > input sentence
                  = correct translation
                  < predicted translation'''

def evaluate_randomly(encoder, decoder, pairs, n=2, trim=100):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_sentence = evaluate(encoder, decoder, pair[0],cutoff_length=trim)
        print('<', output_sentence)
        print('')    
        if create_txt:
            f = open(print_to, 'a')
            f.write("\n \
                > %s \n \
                = %s \n \
                < %s \n" % (pair[0], pair[1], output_sentence))
            f.close()

# %%
'''Used to plot the progress of training. Plots the loss value vs. time'''
def showPlot(times, losses, fig_name):
    x_axis_label = 'Minutes'
    colors = ('red','blue')
    if max(times) >= 120:
        times = [mins/60 for mins in times]
        x_axis_label = 'Hours'
    i = 0
    for key, losses in losses.items():
        if len(losses) > 0:
            plt.plot(times, losses, label=key, color=colors[i])
            i += 1
    plt.legend(loc='upper left')
    plt.xlabel(x_axis_label)
    plt.ylabel('Loss')
    plt.title('Training Results')
    plt.savefig(fig_name+'.png')
    plt.close('all')
    
'''prints the current memory consumption'''
def mem():
    if use_cuda:
        mem = torch.cuda.memory_allocated()/1e7
    else:
        mem = psutil.cpu_percent()
    print('Current mem usage:')
    print(mem)
    return "Current mem usage: %s \n" % (mem)

'''converts a time measurement in seconds to hours'''
def asHours(s):
    m = math.floor(s / 60)
    h = math.floor(m / 60)
    s -= m * 60
    m -= h * 60
    return '%dh %dm %ds' % (h, m, s)

# %%
'''The master function that trains the model. Evlautes progress on the train set
(if present) and also records the progress of training in both a txt file and
a png graph. Also can save the weights of both the Encoder and Decoder 
for future use.'''

def train_and_test(epochs, test_eval_every, plot_every, learning_rate, 
                   lr_schedule, train_pairs, test_pairs, input_lang, 
                   output_lang, batch_size, test_batch_size, encoder, decoder, 
                   loss_criterion, trim, save_weights):

    times = []
    losses = {'train set':[], 'test set': []}

    test_batches, longest_seq, n_o_b = batchify(test_pairs, input_lang, 
                                              output_lang, test_batch_size, 
                                              shuffle_data=False)

    start = time.time()
    for i in range(1,epochs+1):
    
        '''adjust the learning rate according to the learning rate schedule
        specified in lr_schedule'''
        if i in lr_schedule.keys():
            learning_rate /= lr_schedule.get(i)


        encoder.train()
        decoder.train()

        encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
        decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

        batches, longest_seq, n_o_b = batchify(train_pairs, input_lang, 
                                           output_lang, batch_size, 
                                           shuffle_data=True)
        train_loss = train(batches, encoder, decoder, encoder_optimizer, 
                       decoder_optimizer, loss_criterion)
        
        now = time.time()
        print("Iter: %s \nLearning Rate: %s \nTime: %s \nTrain Loss: %s \n" 
          % (i, learning_rate, asHours(now-start), train_loss))

        if create_txt:
            with open(print_to, 'a') as f:
                f.write("Iter: %s \nLeaning Rate: %s \nTime: %s \nTrain Loss: %s \n" \
                    % (i, learning_rate, asHours(now-start), train_loss))

        if i % test_eval_every == 0:
            if test_pairs:
                test_loss = test(test_batches, encoder, decoder, criterion)
                print("Test set loss: %s" % (test_loss))
                if create_txt:
                    with open(print_to, 'a') as f:
                        f.write("Test Loss: %s \n" % (test_loss))
                evaluate_randomly(encoder, decoder, test_pairs, trim)
            else:
                evaluate_randomly(encoder, decoder, train_pairs, trim)

        if i % plot_every == 0:
            times.append((time.time()-start)/60)
            losses['train set'].append(train_loss)
            if test_pairs:
                losses['test set'].append(test_loss)
            showPlot(times, losses, output_file_name)
            if save_weights:
                torch.save(encoder.state_dict(), output_file_name+'_enc_weights.pt')
                torch.save(decoder.state_dict(), output_file_name+'_dec_weights.pt')

# %% [markdown]
# from google.colab import files
# uploaded = files.upload()

# %%
"""PROVIDE INFORMATION ON THE DATASET AND DATASET CLEANING"""

input_lang_name = 'fre'
output_lang_name = 'en'

"""name of your dataset"""
dataset = 'orig'

"""file path of dataset in the form of a tuple. If translated sentences are
stored in two files, this tuple will have two elements"""
raw_data_file_path = ('../data/eng-fra.txt',)

"""True if you want to reverse the order of the sentence pairs. For example, 
in our dataset the sentence pairs list the English sentence first followed by
the French translation. But we want to translate from French to English,
so we set reverse as True."""
reverse=True

"""Remove sentences from dataset that are longer than trim (in either language)"""
trim = 10

"""max number of words in the vocabulary for both languages"""
max_vocab_size= 20000

"""if true removes sentences from the dataset that don't start with eng_prefixes.
Typically will want to use False, but implemented to compare results with Pytorch
tutorial. Can also change the eng_prefixes to prefixes of other languages or
other English prefixes. Just be sure that the prefixes apply to the OUTPUT
language (i.e. the language that the model is translating to NOT from)"""
start_filter = True

"""denotes what percentage of the data to use as training data. the remaining 
percentage becomes test data. Typically want to use 0.8-0.9. 1.0 used here to 
compare with PyTorch results where no test set was utilized"""
perc_train_set = 1.0

# %%
"""OUTPUT OPTIONS"""

"""denotes how often to evaluate a loss on the test set and print
sample predictions on the test set.
if no test set, simply prints sample predictions on the train set."""
test_eval_every = 1

"""denotes how often to plot the loss values of train and test (if applicable)"""
plot_every = 1

"""if true creates a txt file of the output"""
create_txt = True

"""if true saves the encoder and decoder weights to seperate .pt files for later use"""
save_weights = False

# %%
"""HYPERPARAMETERS: FEEL FREE TO PLAY WITH THESE TO TRY TO ACHIEVE BETTER RESULTS"""

"""signifies whether the Encoder and Decoder should be bidirectional LSTMs or not"""
bidirectional = True
if bidirectional:
    directions = 2
else:
    directions = 1

"""number of layers in both the Encoder and Decoder"""
layers = 2

"""Hidden size of the Encoder and Decoder"""
hidden_size = 440

"""Dropout value for Encoder and Decoder"""
dropout = 0.2

"""Training set batch size"""
batch_size = 32

"""Test set batch size"""
test_batch_size = 32

"""number of epochs (full passes through the training data)"""
epochs = 100

"""Initial learning rate"""
learning_rate= 1

"""Learning rate schedule. Signifies by what factor to divide the learning rate
at a certain epoch. For example {5:10} would divide the learning rate by 10
before the 5th epoch and {5:10, 10:100} would divide the learning rate by 10
before the 5th epoch and then again by 100 before the 10th epoch"""
lr_schedule = {}

"""loss criterion, see https://pytorch.org/docs/stable/nn.html for other options"""
criterion = nn.NLLLoss()

# %%
"""******************************************************************
********************NO NEED TO ALTER ANYTHING BELOW******************
******************************************************************"""

use_cuda = torch.cuda.is_available()


"""for plotting of the loss"""
plt.switch_backend('agg')

output_file_name = "testdata.%s_trim.%s_vocab.%s_directions.%s_layers.%s_hidden.%s_dropout.%s_learningrate.%s_batch.%s_epochs.%s" % (dataset,trim,max_vocab_size,directions,layers,hidden_size,dropout,learning_rate,batch_size,epochs)

if create_txt:
    print_to = output_file_name+'.txt'
    with open(print_to, 'w+') as f:
        f.write("Starting Training \n")
else:
    print_to = None

input_lang, output_lang, train_pairs, test_pairs = prepareData(
    input_lang_name, output_lang_name, raw_data_file_path, 
    max_vocab_size=max_vocab_size, reverse=reverse, trim=trim, 
    start_filter=start_filter, perc_train_set=perc_train_set, print_to=print_to)
print('Train Pairs #')
print(len(train_pairs))


"""for gradient clipping from 
https://github.com/pytorch/examples/blob/master/word_language_model/main.py"""
parser = argparse.ArgumentParser(description='PyTorch Wikitext-2 RNN/LSTM Language Model')
parser.add_argument('--clip', type=float, default=0.25,
                    help='gradient clipping')
args = parser.parse_args()

mem()

if create_txt:
    with open(print_to, 'a') as f:
        f.write("\nRandom Train Pair: %s \n\nRandom Test Pair: %s \n\n" 
            % (random.choice(train_pairs),random.choice(test_pairs) 
               if test_pairs else "None"))
        f.write(mem())


"""create the Encoder"""
encoder = EncoderRNN(input_lang.vocab_size, hidden_size, layers=layers, 
                     dropout=dropout, bidirectional=bidirectional)

"""create the Decoder"""
decoder = DecoderAttn(hidden_size, output_lang.vocab_size, layers=layers, 
                      dropout=dropout, bidirectional=bidirectional)

print('Encoder and Decoder Created')
mem()

if use_cuda:
    print('Cuda being used')
    encoder = encoder.cuda()
    decoder = decoder.cuda()

print('Number of epochs: '+str(epochs))

if create_txt:
    with open(print_to, 'a') as f:
        f.write('Encoder and Decoder Created\n')
        f.write(mem())
        f.write("Number of epochs %s \n" % (epochs))

train_and_test(epochs, test_eval_every, plot_every, learning_rate, lr_schedule, 
               train_pairs, test_pairs, input_lang, output_lang, batch_size, 
               test_batch_size, encoder, decoder, criterion, trim, save_weights)
# Out:
# Reading lines...
# Read 135842 sentence pairs
# Trimmed to 10853 sentence pairs
# Counting words...
# Train pairs: 10853
# Test pairs: 0
# Counted Words -> Trimmed Vocabulary Sizes (w/ EOS and SOS tags):
# en, 4487 -> 4490
# fre, 2923 -> 2926
#
# Train Pairs #
# 10853
# Current mem usage:
# 15.0
# Current mem usage:
# 0.0
# Encoder and Decoder Created
# Current mem usage:
# 28.8
# Number of epochs: 100
# Current mem usage:
# 0.0
# Iter: 1
# Learning Rate: 1
# Time: 0h 9m 31s
# Train Loss: 2.639840354594352
#
# > tu es adorable .
# = you re adorable .
# < you re . <EOS>
#
# > nous connaissons la reussite .
# = we re successful .
# < we re very . <EOS>
#
# > elle est tout pour lui .
# = she is everything to him .
# < she is a to to . <EOS>
#
# > t es assez bonne .
# = you re pretty good .
# < you re very . <EOS>
#
# > tu es tres occupee .
# = you re very busy .
# < you re very . <EOS>
#
# > il fait de son mieux .
# = he s doing his best .
# < he is a a to . <EOS>
#
# > je suis suffisamment grand .
# = i m old enough .
# < i m not . <EOS>
#
# > je suis en droit a ma propre opinion .
# = i m entitled to my own opinion .
# < i m to to to . <EOS>
#
# > je ne fais qu une suggestion .
# = i m just making a suggestion .
# < i m not to . <EOS>
#
# > elle est restee dehors sous la pluie .
# = she stayed out in the rain .
# < she is a to to to to to . <EOS>
#
# Iter: 2
# Learning Rate: 1
# Time: 0h 19m 40s
# Train Loss: 1.9985810219206135
#
# > il a vraiment une tenue negligee .
# = he s very sloppy in his dress .
# < he is the the the the the the the . <EOS>
#
# > tu es fidele .
# = you re faithful .
# < you re the the . <EOS>
#
# > elle aurait du etre plus prudente .
# = she should have been more careful .
# < she is the the the the the the . <EOS>
#
# > je suis desole si mes paroles te blessent .
# = i m sorry if my words hurt you .
# < i m sorry i i i i i you . <EOS>
#
# > elles sont tres occupees .
# = they re very busy .
# < they re very very the the . <EOS>
#
# > vous n etes pas tres bon .
# = you re not very good .
# < you re not not the the the the the . <EOS>
#
# > tu es un danseur horrible .
# = you re a terrible dancer .
# < you re a a the the the . <EOS>
#
# > ce n est pas un ami a moi .
# = he is no friend of mine .
# < he is not the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the . <EOS>
#
# > je suis pret a jeter l eponge .
# = i m ready to throw in the towel .
# < i m sorry to i i the the the . <EOS>
#
# > tu es idiot .
# = you re being silly .
# < you re the the the . <EOS>
#
# Iter: 3
# Learning Rate: 1
# Time: 0h 30m 50s
# Train Loss: 1.7724454845846072
#
# > il s inquiete de sa calvitie naissante .
# = he s worried about his receding hairline .
# < he is afraid to is his his his . <EOS>
#
# > elle est affairee comme une abeille .
# = she is as busy as a bee .
# < she is a a a good . <EOS>
#
# > j ai peur de la hauteur .
# = i m scared of heights .
# < i m afraid to i your the . <EOS>
#
# > nous n en sommes pas encore la .
# = we re not yet there .
# < we re not not here . <EOS>
#
# > il est beau et intelligent .
# = he is handsome and clever .
# < he is is a his his . <EOS>
#
# > tu es idiot .
# = you re silly .
# < you re a good . <EOS>
#
# > je me sens seule .
# = i m lonely .
# < i m afraid i your your . <EOS>
#
# > tu te plains toujours .
# = you are always complaining .
# < you re too to as you . <EOS>
#
# > c est un electron libre .
# = he s a loose cannon .
# < he is a a good good . <EOS>
#
# > je ne vous donnerai pas davantage d argent .
# = i m not giving you any more money .
# < i m not not that to this . <EOS>
#
# Iter: 4
# Learning Rate: 1
# Time: 0h 42m 15s
# Train Loss: 1.6008525919031213
#
# > je compte sur toi .
# = i m counting on you .
# < i m too for you . <EOS>
#
# > je me rejouis de vous avoir finalement rencontre .
# = i m glad to finally meet you .
# < i m glad to you you . <EOS>
#
# > je suis impatient .
# = i m impatient .
# < i m a good . <EOS>
#
# > il est dependant a l heroine .
# = he s addicted to heroin .
# < he is a good at the his . <EOS>
#
# > elles sont tres joyeuses .
# = they are very cheerful .
# < they re very very . <EOS>
#
# > nous sommes parfaitement en securite .
# = we re perfectly safe .
# < we re all in the the same . <EOS>
#
# > j en suis vraiment fiere .
# = i m really proud of this .
# < i m a good good . <EOS>
#
# > tu es le chef .
# = you re the leader .
# < you re the one . <EOS>
#
# > nous sommes la tot .
# = we re here early .
# < we re all the the all . <EOS>
#
# > nous sommes habituees a porter des chaussures .
# = we are accustomed to wearing shoes .
# < we re a good her . <EOS>
#
# Iter: 5
# Learning Rate: 1
# Time: 0h 53m 22s
# Train Loss: 1.4590610039034893
#
# > tu es vraiment tres productif aujourd hui .
# = you are really very productive today .
# < you re very very very here . <EOS>
#
# > nous ne sommes pas encore surs .
# = we re still not sure .
# < we re not not yet . <EOS>
#
# > je pars en turquie demain .
# = i m off to turkey tomorrow .
# < i m afraid i all the same . <EOS>
#
# > je ne le fais plus .
# = i m not doing it anymore .
# < i m not the the teacher . <EOS>
#
# > je ne fais que regarder .
# = i m just looking around .
# < i m not your your teacher . <EOS>
#
# > elle a perdu les cles de sa voiture .
# = she s lost her car keys .
# < she is her his his his . <EOS>
#
# > il est impopulaire pour une raison quelconque .
# = he is unpopular for some reason .
# < he is a good a child . <EOS>
#
# > ce sont de chics types .
# = they re nice guys .
# < they are in the same . <EOS>
#
# > je creve d envie d une boisson fraiche .
# = i am dying for a cold drink .
# < i m afraid i my a teacher . <EOS>
#
# > vous etes beaux .
# = you are beautiful .
# < you re the teacher . <EOS>
#
# Iter: 6
# Learning Rate: 1
# Time: 1h 4m 24s
# Train Loss: 1.3409547211185366
#
# > je rencontre quelqu un pour diner .
# = i m meeting someone for dinner .
# < i m going to a new job . <EOS>
#
# > c est un gentleman .
# = he is quite a gentleman .
# < he is a bit man . <EOS>
#
# > je suis la pour vous proteger .
# = i m here to protect you .
# < i m here for you . <EOS>
#
# > tu n es plus seule .
# = you re not alone anymore .
# < you re not like anymore . <EOS>
#
# > tu es le doyen .
# = you re the oldest .
# < you re the one . <EOS>
#
# > il est plus intelligent que moi .
# = he is more clever than me .
# < he is taller than i am . <EOS>
#
# > je suis prepare a mourir .
# = i am ready to die .
# < i m about to be . <EOS>
#
# > je vais passer a la television .
# = i m going to be on tv .
# < i m going to be the same . <EOS>
#
# > je suis votre voisin .
# = i m your neighbor .
# < i m your your teacher . <EOS>
#
# > tu es exactement comme ta mere .
# = you re just like your mother .
# < you re as as as your your friend . <EOS>
#
# Iter: 7
# Learning Rate: 1
# Time: 1h 16m 6s
# Train Loss: 1.2406475341659964
#
# > elles sont toutes mortes .
# = they re all dead .
# < they re all all here . <EOS>
#
# > vous etes tres contrariee .
# = you re very upset .
# < you re very very upset . <EOS>
#
# > je suis plutot heureux .
# = i m fairly happy .
# < i m happy happy happy . <EOS>
#
# > vous etes assez bonnes .
# = you re pretty good .
# < you re very good . <EOS>
#
# > nous sommes depourvues de prejuges .
# = we re unprejudiced .
# < we re out of that . <EOS>
#
# > il est en colere apres tout le monde .
# = he s mad at everyone .
# < he is always at all the same . <EOS>
#
# > je suis la plus jeune enfant .
# = i m the youngest child .
# < i m the only only child . <EOS>
#
# > tu es sauve .
# = you re safe .
# < you re a teacher . <EOS>
#
# > c est un fondu de musique .
# = he is mad about music .
# < he is a man of man . <EOS>
#
# > il n est pas aussi grand que toi .
# = he s not as tall as you are .
# < he s not as as as as you are . <EOS>
#
# Iter: 8
# Learning Rate: 1
# Time: 1h 29m 52s
# Train Loss: 1.1536804891890764
#
# > il est photogenique .
# = he is photogenic .
# < he is kind . <EOS>
#
# > tu es grognon .
# = you re grumpy .
# < you re my teacher . <EOS>
#
# > nous retournons en arriere .
# = we re going back .
# < we re going to be up . <EOS>
#
# > il est intelligent .
# = he is intelligent .
# < he is busy s busy . <EOS>
#
# > vous me tuez .
# = you re killing me .
# < you re going to me me . <EOS>
#
# > elle est fachee la .
# = she s upset right now .
# < she is still at the same . <EOS>
#
# > elle a tres peur des chiens .
# = she s very afraid of dogs .
# < she is very afraid of her time . <EOS>
#
# > ils se trouvent juste derriere moi .
# = they re right behind me .
# < they re right behind i am . <EOS>
#
# > vous etes tatillons .
# = you re finicky .
# < you re very young . <EOS>
#
# > c est une eleve de deuxieme annee .
# = she is a second year student .
# < she is a very student of our student . <EOS>
#
# Iter: 9
# Learning Rate: 1
# Time: 1h 44m 20s
# Train Loss: 1.0756254636198135
#
# > nous sommes consciencieux .
# = we re conscientious .
# < we re out of we . <EOS>
#
# > il etudie l histoire a l universite .
# = he is studying history at the university .
# < he is always in the game . <EOS>
#
# > je suis trop fatigue pour sortir courir .
# = i m too tired to go out jogging .
# < i m too tired to do do to do . <EOS>
#
# > je vais etre malade .
# = i m going to be sick .
# < i m going to be happy . <EOS>
#
# > elle est mal elevee .
# = she is bad mannered .
# < she s a new liar . <EOS>
#
# > elle depend encore de ses parents .
# = she still depends on her parents .
# < she is always always her her . <EOS>
#
# > nous ne sommes pas ouvertes .
# = we re not open .
# < we re not not sure . <EOS>
#
# > vous etes bon avec les enfants .
# = you re good with kids .
# < you are good at the same time . <EOS>
#
# > je suis plus vif que vous .
# = i m smarter than you .
# < i m more than you . <EOS>
#
# > je ne m en vais pas .
# = i m not going away .
# < i m not going . <EOS>
#
# Iter: 10
# Learning Rate: 1
# Time: 1h 58m 48s
# Train Loss: 1.0047277455562764
#
# > je ne parle pas avec toi .
# = i m not talking to you .
# < i m not getting with you . <EOS>
#
# > nous sommes jumeaux .
# = we re twins .
# < we re a teacher . <EOS>
#
# > tu agis comme une enfant .
# = you re acting like a child .
# < you re like a child . <EOS>
#
# > tu es fort habile .
# = you re very clever .
# < you re very funny . <EOS>
#
# > c est bien .
# = i m glad to hear that .
# < i m busy busy now . <EOS>
#
# > je suis tellement embarrasse .
# = i m so embarrassed .
# < i m so so tired . <EOS>
#
# > vous etes fort effronte .
# = you re very forward .
# < you re very busy . <EOS>
#
# > nous sommes a la moitie du chemin .
# = we re halfway there .
# < we re on the same team . <EOS>
#
# > elle me montra quelle robe porter .
# = she showed me which dress to wear .
# < she showed me a lot today . <EOS>
#
# > nous allons a nouveau etre en retard .
# = we re going to be late again .
# < we re going to be late . <EOS>
#
# Iter: 11
# Learning Rate: 1
# Time: 2h 14m 18s
# Train Loss: 0.9449894690505797
#
# > elle est photographe professionnelle .
# = she s a professional photographer .
# < she is a bad person . <EOS>
#
# > nous sommes tous retraites .
# = we re all retired .
# < we re all all all . <EOS>
#
# > tu es belle .
# = you are beautiful .
# < you re a smart girl . <EOS>
#
# > je m occupe de mon grand pere .
# = i m taking care of my grandfather
# < i m afraid of my father . <EOS>
#
# > ils ne sont pas encore a la maison .
# = they re not home yet .
# < they re not home yet . <EOS>
#
# > je suis familier de sa musique .
# = i am familiar with his music .
# < i m proud of his english . <EOS>
#
# > nous sommes censes etre ensemble .
# = we re meant to be together .
# < we re almost ready to be being . <EOS>
#
# > nous prenons l ascendant .
# = we re taking over .
# < we re going in the same . <EOS>
#
# > ils sont medecins .
# = they re doctors .
# < they re mine . <EOS>
#
# > vous faites la bonne chose .
# = you re doing the right thing .
# < you re doing the same right . <EOS>
#
# Iter: 12
# Learning Rate: 1
# Time: 2h 30m 49s
# Train Loss: 0.8839568153438864
#
# > je vais etre ton avocat .
# = i m going to be your lawyer .
# < i m going to be your teacher . <EOS>
#
# > vous etes un horrible individu .
# = you re a terrible person .
# < you re a funny person . <EOS>
#
# > tu es tout a fait attirant .
# = you re quite attractive .
# < you re very attractive to late . <EOS>
#
# > tu n es pas normale .
# = you re not normal .
# < you re not a doctor . <EOS>
#
# > je suis simplement fatiguee .
# = i m just tired .
# < i m really happy . <EOS>
#
# > il est joueur de tennis .
# = he s a tennis player .
# < he is a good tennis student . <EOS>
#
# > vous etes tres bonnes .
# = you re very good .
# < you re very good . <EOS>
#
# > elle parle bien anglais .
# = she is a good english speaker .
# < she is good at english english . <EOS>
#
# > il fait partie de mes amis .
# = he is included among my friends .
# < he s doing my friends friends . <EOS>
#
# > je prends deux jours de conge .
# = i m taking a couple of days off .
# < i m taking a couple of a job . <EOS>
#
# Iter: 13
# Learning Rate: 1
# Time: 2h 46m 40s
# Train Loss: 0.8323551703108915
#
# > vous etes tire d affaire .
# = you re off the hook .
# < you re free about the hook . <EOS>
#
# > je tente de te parler .
# = i m trying to talk to you .
# < i m looking to meet you . <EOS>
#
# > tu n es pas une sainte .
# = you re no saint .
# < you re not a doctor . <EOS>
#
# > il plaisante toujours .
# = he is always joking .
# < he is always always always alive . <EOS>
#
# > il est dramaturge .
# = he is a dramatist .
# < he s a teacher . <EOS>
#
# > je suis completement saoul .
# = i m totally drunk .
# < i m totally your teacher . <EOS>
#
# > elle est sous la chaise .
# = she s under the chair .
# < she s the first . <EOS>
#
# > vous etes celle la .
# = you are the one .
# < you re the one here . <EOS>
#
# > elle voyage autour du monde .
# = she is traveling around the world .
# < she is fond of the same game . <EOS>
#
# > je suis desole nous avons ete devalises .
# = i m sorry we re completely sold out .
# < i m sorry we re ready out . <EOS>
#
# Iter: 14
# Learning Rate: 1
# Time: 3h 3m 20s
# Train Loss: 0.7798526032953257
#
# > tu n ecoutes pas !
# = you re not listening !
# < you re not invited . <EOS>
#
# > je suis veinard .
# = i m lucky .
# < i m a teacher . <EOS>
#
# > vous n etes d aucune aide .
# = you re no help .
# < you re not help your help . <EOS>
#
# > j achete des fruits et du chocolat .
# = i m buying fruit and chocolate .
# < i m very fond of the lot . <EOS>
#
# > elles n ont pas toujours raison .
# = they re not always right .
# < they re not always right . <EOS>
#
# > tu es trop maigrichonne .
# = you re too skinny .
# < you re too too slow . <EOS>
#
# > je suis ton ami .
# = i m your friend .
# < i m your friend . <EOS>
#
# > j ai plus de dix huit ans .
# = i m over eighteen .
# < i m sick . <EOS>
#
# > nous sommes cousines .
# = we re cousins .
# < we are busy . <EOS>
#
# > c est un americain d origine asiatique .
# = he s an asian american .
# < he s a member of the cold . <EOS>
#
# Iter: 15
# Learning Rate: 1
# Time: 3h 20m 14s
# Train Loss: 0.7366601698791658
#
# > il est juste la .
# = he s right here .
# < he s here here he . <EOS>
#
# > ils viennent nous chercher .
# = they re coming for us .
# < they re just just better . <EOS>
#
# > tu n es pas comme moi .
# = you re not like me .
# < you aren t like me . <EOS>
#
# > c est une fille tres chouette .
# = she s a very nice girl .
# < she is a very nice girl . <EOS>
#
# > tu es sur le mauvais bateau .
# = you re on the wrong ship .
# < you re on the wrong today . <EOS>
#
# > je ne suis pas ce genre de fille .
# = i m not that kind of girl .
# < i m not that kind of girl . <EOS>
#
# > je me specialise en sociologie .
# = i m majoring in sociology .
# < i m getting getting taking a couple . <EOS>
#
# > je suis fatigue de faire la queue .
# = i m tired of waiting in line .
# < i m tired of waiting in the team . <EOS>
#
# > tu es negligente .
# = you re careless .
# < you re a teacher . <EOS>
#
# > elle l a vu manger un sandwich .
# = she saw him eating a sandwich .
# < she saw him a letter . <EOS>
#
# Iter: 16
# Learning Rate: 1
# Time: 3h 37m 0s
# Train Loss: 0.6911483331728435
#
# > vous etes trop vieilles pour moi .
# = you re too old for me .
# < you re too old for me . <EOS>
#
# > je suis tellement fiere de vous .
# = i m so proud of you .
# < i m so proud of you . <EOS>
#
# > il grossit .
# = he is putting on weight .
# < he s lying . <EOS>
#
# > je suis tres serieux .
# = i m quite serious .
# < i m very very serious . <EOS>
#
# > je ne suis pas invite a des fetes .
# = i m not invited to parties .
# < i m not invited to the go . <EOS>
#
# > nous ne sommes pas prisonniers .
# = we re not prisoners .
# < we re not not the millionaire . <EOS>
#
# > ils sont a l exterieur .
# = they re outside .
# < they re at all out . <EOS>
#
# > j epargne pour une voiture .
# = i m saving money for a car .
# < i m waiting for a car car . <EOS>
#
# > je suis presque aussi grand que tom .
# = i m almost as tall as tom .
# < i m almost as tall as tom . <EOS>
#
# > c est un esprit independant .
# = she s an independent thinker .
# < he s a bad writer . <EOS>
#
# Iter: 17
# Learning Rate: 1
# Time: 3h 55m 15s
# Train Loss: 0.651176894828555
#
# > c est ma s ur .
# = she s my sister .
# < she s my sister . <EOS>
#
# > je ne suis pas tellement bon en tennis .
# = i m not so good at tennis .
# < i m not a doctor at tennis . <EOS>
#
# > il joue avec mon chat .
# = he s playing with my cat .
# < he is in my way with my father . <EOS>
#
# > il a l esprit vif .
# = he is sharp witted .
# < he is always complaining . <EOS>
#
# > j en ai assez de tes recriminations .
# = i m sick of your complaints .
# < i m tired of your complaints . <EOS>
#
# > je suis etudiant a l universite d oxford .
# = i am a student at oxford university .
# < i am a student at university university . <EOS>
#
# > je vais appeler la police .
# = i m going to call the police .
# < i m going to go the game . <EOS>
#
# > je ressens des brulures d estomac .
# = i m experiencing some heartburn .
# < i m dying some some some cold . <EOS>
#
# > il lui est tres attache .
# = he is deeply attached to her .
# < he is s very poor . <EOS>
#
# > c est une infirmiere attitree .
# = she is qualified as a nurse .
# < she is a nice girl . <EOS>
#
# Iter: 18
# Learning Rate: 1
# Time: 4h 14m 12s
# Train Loss: 0.6114752552853923
#
# > ca ne m amuse pas .
# = i m not amused .
# < i m not listening . <EOS>
#
# > tu es prudent .
# = you re careful .
# < you re attractive . <EOS>
#
# > je n en suis pas trop etonnee .
# = i m not that surprised by it .
# < i m not too convinced . <EOS>
#
# > nous sommes impuissantes .
# = we re helpless .
# < we re a university friend . <EOS>
#
# > elle m embrassa subitement .
# = she suddenly kissed me .
# < she showed me me . <EOS>
#
# > elle le frappa au visage .
# = she slapped him in the face .
# < she scolded him in the problem . <EOS>
#
# > vous etes bon .
# = you are good .
# < you are good . <EOS>
#
# > j appelle de mon telephone cellulaire .
# = i m calling from my cell phone .
# < i m trying with my new game . <EOS>
#
# > je ne suis pas vegetarienne .
# = i m not a vegetarian .
# < i m not a doctor . <EOS>
#
# > il est trop ivre .
# = he s too drunk .
# < he s too drunk . <EOS>
#
# Iter: 19
# Learning Rate: 1
# Time: 4h 34m 7s
# Train Loss: 0.5745510450780138
#
# > je viens de turquie .
# = i m from turkey .
# < i m from dying to die . <EOS>
#
# > vous etes dement .
# = you re demented .
# < you re open . <EOS>
#
# > tu es tres elegante .
# = you re very sophisticated .
# < you re very very funny . <EOS>
#
# > je ne suis pas presse de partir .
# = i m in no hurry to leave .
# < i m not allowed to leave . <EOS>
#
# > elles sont toutes fausses .
# = they re all fake .
# < they re all all . <EOS>
#
# > je ne suis plus tout jeune .
# = i m not young anymore .
# < i m not young anymore . <EOS>
#
# > j attends le dejeuner .
# = i m waiting for lunch .
# < i m waiting for the job . <EOS>
#
# > c est un pauvre type sans c ur .
# = he s a cold hearted jerk .
# < he s a talented and hook . <EOS>
#
# > ils sont russes .
# = they are russian .
# < they are tired . <EOS>
#
# > c est une mauvaise personne .
# = she is a bad person .
# < she is a bad person . <EOS>
#
# Iter: 20
# Learning Rate: 1
# Time: 4h 53m 50s
# Train Loss: 0.5439192865294182
#
# > tu n es pas comme les autres .
# = you aren t like the others .
# < you aren t like the others . <EOS>
#
# > vous mentez n est ce pas ?
# = you re lying aren t you ?
# < you re worried aren t you ? <EOS>
#
# > je suis egalement heureuse .
# = i m happy too .
# < i m happy too . <EOS>
#
# > je suis votre nouvel avocat .
# = i m your new lawyer .
# < i m your new lawyer . <EOS>
#
# > elle est sure de reussir .
# = she s sure to succeed .
# < she is sure to succeed . <EOS>
#
# > je ne suis pas un bon pecheur .
# = i m not good at fishing .
# < i m not good at all . <EOS>
#
# > il va au concert .
# = he is going to the concert .
# < he s going to win the job . <EOS>
#
# > je suis fort modeste .
# = i m very modest .
# < i m very smart . <EOS>
#
# > je suis seulement fatigue .
# = i m just tired .
# < i m just tired . <EOS>
#
# > je reste pour quelques autres semaines .
# = i am staying for another few weeks .
# < i am working for a few days . <EOS>
#
# Iter: 21
# Learning Rate: 1
# Time: 5h 13m 50s
# Train Loss: 0.5096933997837841
#
# > nous sommes australiennes .
# = we are australian .
# < we re close . <EOS>
#
# > je suis assez heureuse .
# = i m quite happy .
# < i m happy enough . <EOS>
#
# > vous etes decues n est ce pas ?
# = you re disappointed aren t you ?
# < you re worried aren t you ? <EOS>
#
# > vous etes tres vifs .
# = you re very sharp .
# < you re very wise . <EOS>
#
# > il est a l article de la mort .
# = he is about to die .
# < he is used to death . <EOS>
#
# > nous sommes dans les temps .
# = we re on schedule .
# < we re in trouble . <EOS>
#
# > vous vous plaignez toujours .
# = you re always complaining .
# < you re always complaining . <EOS>
#
# > nous n avons pas encore fini de jouer .
# = we re not done playing yet .
# < we re not done on this . <EOS>
#
# > je suis tres a l aise .
# = i m very comfortable .
# < i m very comfortable . <EOS>
#
# > je suis abasourdi .
# = i m flabbergasted .
# < i m already all sure . <EOS>
#
# Iter: 22
# Learning Rate: 1
# Time: 5h 34m 37s
# Train Loss: 0.4793838264746026
#
# > je suis desole mais tu dois partir .
# = i m sorry but you need to leave .
# < i m sorry but you need to leave . <EOS>
#
# > je suis desole je ne te reconnais pas .
# = i m sorry i don t recognize you .
# < i m sorry i don t recognize you . <EOS>
#
# > en un sens tu as raison .
# = you are right in a way .
# < you re up in a way . <EOS>
#
# > il n est pas idiot .
# = he s not stupid .
# < he s not a fool . <EOS>
#
# > je ne trouve pas les mots .
# = i m at a loss for words .
# < i m not a beer . <EOS>
#
# > nous plaisantons .
# = we re kidding .
# < we re having fun . <EOS>
#
# > il est encore celibataire .
# = he s still single .
# < he s still single . <EOS>
#
# > t es un gars marrant .
# = you re a funny guy .
# < you re a funny guy . <EOS>
#
# > vous etes tellement difficiles !
# = you re so picky .
# < you re so sweet . <EOS>
#
# > j ai le c ur brise .
# = i m heartbroken .
# < i m acquainted . <EOS>
#
# Iter: 23
# Learning Rate: 1
# Time: 5h 56m 3s
# Train Loss: 0.45187037877276953
#
# > il a le cancer des poumons .
# = he s got lung cancer .
# < he is making making mistakes . <EOS>
#
# > je ne vous blame pas .
# = i m not blaming you .
# < i m not giving you . <EOS>
#
# > nous sommes fauches .
# = we re broke .
# < we re broke . <EOS>
#
# > tu agis comme une enfant .
# = you re acting like a child .
# < you re acting like a child . <EOS>
#
# > je suis entre deux emplois .
# = i m between jobs .
# < i m between jobs . <EOS>
#
# > je suis desole de vous avoir blesse .
# = i m sorry i hurt you .
# < i m sorry i hurt you . <EOS>
#
# > tu es responsable de ce resultat .
# = you are responsible for the result .
# < you are responsible for this result . <EOS>
#
# > il est capitaine de l equipe .
# = he is the captain of the team .
# < he is the one of the team . <EOS>
#
# > je suis si malade .
# = i am so sick .
# < i m so sick . <EOS>
#
# > vous etes plus intelligent que moi .
# = you re smarter than me .
# < you re smarter than me . <EOS>
#
# Iter: 24
# Learning Rate: 1
# Time: 6h 17m 30s
# Train Loss: 0.4228452902881875
#
# > tu n es plus un enfant .
# = you are not a child anymore .
# < you are not a child anymore . <EOS>
#
# > je ne suis pas aussi occupee que tom .
# = i m not as busy as tom .
# < i m not as busy as tom . <EOS>
#
# > c est un grand farceur .
# = he is a big prankster .
# < he s a big great guy . <EOS>
#
# > nous descendons .
# = we re going down .
# < we re getting getting . <EOS>
#
# > il est son propre maitre .
# = he is his own master .
# < he is his his own own . <EOS>
#
# > c est un professeur d anglais .
# = he is a teacher of english .
# < he s a teacher of english . <EOS>
#
# > tu es trop ivre pour conduire .
# = you re too drunk to drive .
# < you re too too drunk to drive . <EOS>
#
# > tu es surmene .
# = you re overworked .
# < you re big our interesting . <EOS>
#
# > je suis en train de cooperer .
# = i m cooperating .
# < i m having a gas . <EOS>
#
# > elle trouve toujours des defauts a son mari .
# = she is always finding fault with her husband .
# < she is always finding at her her husband . <EOS>
#
# Iter: 25
# Learning Rate: 1
# Time: 6h 38m 52s
# Train Loss: 0.3982091099111732
#
# > nous sommes pieges !
# = we re trapped !
# < we re shocked . <EOS>
#
# > je cherche un correspondant francais .
# = i m looking for a french penpal .
# < i m looking for a french french . <EOS>
#
# > je suis fier de mon ecole .
# = i m proud of my school .
# < i m proud of my school . <EOS>
#
# > c est un gros mangeur .
# = he is a big eater .
# < he is a big great worker . <EOS>
#
# > tu vas etre pere .
# = you re going to be a father .
# < you re going to be a father . <EOS>
#
# > elle le vit conduire sa nouvelle voiture .
# = she saw him driving his new car .
# < she saw him driving his new car . <EOS>
#
# > vous n etes pas autorises a stationner la .
# = you aren t allowed to park there .
# < you re not allowed to park there . <EOS>
#
# > je ne suis pas satisfaite .
# = i m not satisfied .
# < i m not satisfied . <EOS>
#
# > nous sommes tous a court de carburant .
# = we re all out of booze .
# < we re all out of booze . <EOS>
#
# > je suis un etranger .
# = i m a foreigner .
# < i am a new student . <EOS>
#
# Iter: 26
# Learning Rate: 1
# Time: 7h 0m 46s
# Train Loss: 0.37412374697916245
#
# > c est un sectaire .
# = he s a bigot .
# < he s a heroin person . <EOS>
#
# > nous sommes freres de sang .
# = we re blood brothers .
# < we re out of brothers . <EOS>
#
# > ils peuvent chanter .
# = they re able to sing .
# < they re able to sing . <EOS>
#
# > tu vas bien .
# = you re all right .
# < you re fine . <EOS>
#
# > je me suis amende .
# = i m reformed .
# < i m married . <EOS>
#
# > je suis sur d avoir ferme le gaz .
# = i m sure i turned off the gas .
# < i m sure i turned off the gas . <EOS>
#
# > tu es etourdi .
# = you re forgetful .
# < you re on the chair . <EOS>
#
# > je ne vais nulle part avec ma voiture .
# = i m not driving anywhere .
# < i m not driving you car . <EOS>
#
# > je suis content de vous aider .
# = i am glad to help you .
# < i m glad to help you . <EOS>
#
# > je suis ravi de t aider .
# = i am glad to help you .
# < i m glad to help you . <EOS>
#
# Iter: 27
# Learning Rate: 1
# Time: 7h 22m 43s
# Train Loss: 0.3521712481330865
#
# > il t attend chez moi .
# = he s waiting for you at home .
# < he s waiting for you at home . <EOS>
#
# > je suis assez contente .
# = i m happy enough .
# < i m happy enough . <EOS>
#
# > nous n en sommes pas encore convaincues .
# = we re not convinced yet .
# < we re not yet yet . <EOS>
#
# > je ne suis pas riche .
# = i m not rich .
# < i m not a millionaire . <EOS>
#
# > je suis tres inquiet a ton sujet .
# = i m very worried about you .
# < i m very worried about you . <EOS>
#
# > nous sommes en train de le reparer .
# = we re fixing it .
# < we re losing it . <EOS>
#
# > vous etes une fille interessante .
# = you re an interesting girl .
# < you re an girl girl . <EOS>
#
# > je ne vais pas vous faire de mal .
# = i m not going to hurt you .
# < i m not going to hurt you . <EOS>
#
# > je suis sur qu elles vont gagner .
# = i m sure they ll win .
# < i m sure they ll win . <EOS>
#
# > je suis juste preoccupe par mon poids .
# = i m just worried about my weight .
# < i m just worried about my weight . <EOS>
#
# Iter: 28
# Learning Rate: 1
# Time: 7h 44m 53s
# Train Loss: 0.3299853482155751
#
# > nous nous en sortons tres bien .
# = we re managing all right .
# < we re doing all right now . <EOS>
#
# > ce ne sont pas mes regles .
# = they re not my rules .
# < they re not my words . <EOS>
#
# > je me trouve actuellement a l aeroport .
# = i m at the airport right now .
# < i m at the airport now . <EOS>
#
# > elle vend des fleurs .
# = she sells flowers .
# < she sells flowers . <EOS>
#
# > c est un grand scientifique .
# = he is a great scientist .
# < he is a great writer . <EOS>
#
# > il revasse toujours .
# = he is always day dreaming .
# < he is always always day day . <EOS>
#
# > tu agis comme une enfant .
# = you re acting like a child .
# < you re acting like a child . <EOS>
#
# > ils parlent en francais .
# = they re speaking french .
# < they re taking french . <EOS>
#
# > je suis mort de fatigue .
# = i m dead tired .
# < i m sorry i m tired . <EOS>
#
# > nous sommes tous ensemble a l instant .
# = we re all together right now .
# < we re all together right now . <EOS>
#
# Iter: 29
# Learning Rate: 1
# Time: 8h 7m 21s
# Train Loss: 0.3081725827595008
#
# > il cherche actuellement un nouveau poste .
# = he is seeking a new position .
# < he is seeking a new new new job . <EOS>
#
# > nous sommes consciencieuses .
# = we re conscientious .
# < we re prisoners . <EOS>
#
# > je suis habitue a rester debout tard .
# = i m used to staying up late .
# < i am accustomed to staying up late . <EOS>
#
# > je ne suis pas du tout fatigue .
# = i m not at all tired .
# < i m not a bit tired . <EOS>
#
# > c est vous l enseignante .
# = you re the teacher .
# < you re the teacher . <EOS>
#
# > tu es entete .
# = you re stubborn .
# < you re being pathetic . <EOS>
#
# > je ne suis pas comme les autres gens .
# = i m not like other people .
# < i m not like people people . <EOS>
#
# > tu vas beaucoup me manquer .
# = i m going to miss you a lot .
# < you re going to miss too a lot . <EOS>
#
# > vous etes trop jeunes pour voyager seules .
# = you are too young to travel alone .
# < you are too young to travel alone . <EOS>
#
# > nous ne sommes pas partenaires .
# = we re not partners .
# < we re not partners . <EOS>
#
# Iter: 30
# Learning Rate: 1
# Time: 8h 29m 23s
# Train Loss: 0.2890958736857913
#
# > vous etes exactement comme votre mere .
# = you re just like your mother .
# < you re just like your mother . <EOS>
#
# > vous etes fort comprehensives .
# = you re very understanding .
# < you re very young . <EOS>
#
# > elle n est pas toujours heureuse .
# = she is not always happy .
# < she is not always happy . <EOS>
#
# > je ne me plains pas .
# = i m not complaining .
# < i m not giving up . <EOS>
#
# > il est docteur et professeur d universite .
# = he is a doctor and a university professor .
# < he is a teacher and a university university . <EOS>
#
# > je commence a avoir faim .
# = i m getting hungry .
# < i m beginning to get hungry . <EOS>
#
# > c est une taquine .
# = she s a big teaser .
# < she s a wonderful girl . <EOS>
#
# > tu n y vas pas si ?
# = you re not going are you ?
# < you re not going are you ? <EOS>
#
# > c est un ami tres proche .
# = he is my close friend .
# < he is a friend friend . <EOS>
#
# > elle est adorable .
# = she s adorable .
# < she s related a mother . <EOS>
#
# Iter: 31
# Learning Rate: 1
# Time: 8h 52m 0s
# Train Loss: 0.27124791898246026
#
# > elle hurla a l aide .
# = she screamed for help .
# < she struggled to help him . <EOS>
#
# > il n est pas des notres .
# = he s not one of us .
# < he s not one of us . <EOS>
#
# > vous etes soucieux n est ce pas ?
# = you re worried aren t you ?
# < you re worried aren t you ? <EOS>
#
# > j attends cela avec impatience .
# = i m looking forward to it .
# < i m looking forward to the place . <EOS>
#
# > elle travaille dur ce semestre .
# = she is working hard this semester .
# < she is working hard this morning . <EOS>
#
# > je suis amoureuse de toi .
# = i m in love with you .
# < i m in love with you . <EOS>
#
# > nous ne sommes pas interesses .
# = we re not interested .
# < we re not interested . <EOS>
#
# > elle ne devrait pas s y rendre seule .
# = she shouldn t go by herself .
# < she shouldn t go by herself . <EOS>
#
# > nous sommes toujours prudentes .
# = we re always careful .
# < we re always open . <EOS>
#
# > je ne suis pas un drogue .
# = i m not a drug addict .
# < i m not a drug addict . <EOS>
#
# Iter: 32
# Learning Rate: 1
# Time: 9h 14m 24s
# Train Loss: 0.25438478355699196
#
# > je suis un bon garcon .
# = i am a good boy .
# < i m a good boy . <EOS>
#
# > j en suis contente .
# = i m happy with that .
# < i m happy with it . <EOS>
#
# > je ne vais pas te le repeter .
# = i m not going to tell you again .
# < i m not going to tell you again . <EOS>
#
# > j ai bien peur qu elle va echouer .
# = i m afraid she will fail .
# < i m afraid she will have try . <EOS>
#
# > nous sommes trop occupes .
# = we re too busy .
# < we re too busy . <EOS>
#
# > il est comme un pere pour moi .
# = he is like a father to me .
# < he is like a father to me . <EOS>
#
# > je ne suis souvent qu a moitie reveillee .
# = i m often only half awake .
# < i m often only half awake . <EOS>
#
# > c est quelqu un de bien .
# = he s a good person .
# < he s a nice student . <EOS>
#
# > tu es fort comprehensif .
# = you re very understanding .
# < you re very understanding . <EOS>
#
# > je derange .
# = i m interfering .
# < i m dying . <EOS>
#
# Iter: 33
# Learning Rate: 1
# Time: 9h 37m 5s
# Train Loss: 0.2381020715024893
#
# > elles sont toutes fausses .
# = they re all fake .
# < they re all all . <EOS>
#
# > elle n est pas chanteuse .
# = she s no singer .
# < she is no singer . <EOS>
#
# > je me trouve juste derriere toi .
# = i m right behind you .
# < i m right behind you . <EOS>
#
# > je suis impatient de te revoir .
# = i am looking forward to seeing you again .
# < i m looking forward to seeing you again . <EOS>
#
# > tu es tres sage .
# = you re very wise .
# < you re very wise . <EOS>
#
# > il est aux anges .
# = he s tickled pink .
# < he is an american addict . <EOS>
#
# > tu es tres ingenieux .
# = you re very clever .
# < you re very clever . <EOS>
#
# > je travaille dans la recherche contre le sida .
# = i am engaged in aids research .
# < i am in aids aids next . <EOS>
#
# > il est rouille .
# = he s out of practice .
# < he is out of practice . <EOS>
#
# > je suis dans la maison .
# = i m in the house .
# < i m in the house . <EOS>
#
# Iter: 34
# Learning Rate: 1
# Time: 10h 0m 29s
# Train Loss: 0.22332581508671498
#
# > je suis malade .
# = i m ill .
# < i m sick . <EOS>
#
# > je suis inquiet de votre attitude irresponsable .
# = i am alarmed by your irresponsible attitude .
# < i am alarmed by your irresponsible attitude . <EOS>
#
# > c est le chef de classe .
# = he is at the head of the class .
# < he is the class class . <EOS>
#
# > il est ici pour nous espionner .
# = he s here to spy on us .
# < he s here to spy on us . <EOS>
#
# > je ne suis pas occupee du tout .
# = i m not at all busy .
# < i m not at all busy . <EOS>
#
# > vous etes tres riches .
# = you are very rich .
# < you re very rich . <EOS>
#
# > vous allez adorer nos plats .
# = you re going to love our food .
# < you re going to be on food . <EOS>
#
# > je suis en train de danser .
# = i m dancing .
# < i m dancing . <EOS>
#
# > il fait les preparatifs pour un voyage .
# = he is making preparations for a trip .
# < he is making making preparations for a trip . <EOS>
#
# > je suis la pour te proteger .
# = i m here to protect you .
# < i m here to protect you . <EOS>
#
# Iter: 35
# Learning Rate: 1
# Time: 10h 23m 41s
# Train Loss: 0.20854011479849424
#
# > je suis heureux que vous ayez mentionne cela .
# = i m glad you brought this up .
# < i m glad you brought this up . <EOS>
#
# > je vais regarder la tele .
# = i m going to watch tv .
# < i m going to watch tv . <EOS>
#
# > je n ai pas honte d etre pauvre .
# = i m not ashamed that i am poor .
# < i m not ashamed that poor . <EOS>
#
# > il est accoutume a voyager .
# = he is used to traveling .
# < he is used to traveling . <EOS>
#
# > je me casse .
# = i m hitting the road .
# < i m getting a bath . <EOS>
#
# > je ne suis pas pret .
# = i m not ready .
# < i m not ready . <EOS>
#
# > comme tu es mignonne .
# = you are so cute .
# < you are so pretty . <EOS>
#
# > je fais mes devoirs .
# = i m doing my homework .
# < i am doing my homework . <EOS>
#
# > tu es celui la .
# = you are the one .
# < you re the one here . <EOS>
#
# > je suis content que nous ayons vu tom .
# = i m glad we saw tom .
# < i m glad we used to tom . <EOS>
#
# Iter: 36
# Learning Rate: 1
# Time: 10h 47m 0s
# Train Loss: 0.19392203695752191
#
# > je n y suis pas interesse .
# = i m not interested in that .
# < i m not very interested in this . <EOS>
#
# > il s en met plein les poches .
# = he s raking it in .
# < he s raking it in . <EOS>
#
# > je suis endurant .
# = i m resilient .
# < i m a vegetarian . <EOS>
#
# > nous avons tous deux tort .
# = we re both wrong .
# < we re both wrong . <EOS>
#
# > vous etes trop dure avec vous .
# = you re too hard on yourself .
# < you re too hard on yourself . <EOS>
#
# > elles parlent .
# = they re talking .
# < they re talking . <EOS>
#
# > il est maintenant a court d argent .
# = he s now short of money .
# < he s now short of money . <EOS>
#
# > il est habitue au travail .
# = he is accustomed to the work .
# < he s used to work . <EOS>
#
# > nous sommes seuls .
# = we re on our own .
# < we re out of our time . <EOS>
#
# > je le connais bien .
# = i am well acquainted with him .
# < i am doing this good well . <EOS>
#
# Iter: 37
# Learning Rate: 1
# Time: 11h 10m 15s
# Train Loss: 0.1811030481651703
#
# > je ne suis pas ton professeur .
# = i m not your teacher .
# < i m not your teacher . <EOS>
#
# > ils sculptent une statue de marbre .
# = they are chiseling a statue out of marble .
# < they are a little out of do . <EOS>
#
# > je ne suis pas encore si desesperee .
# = i m not that desperate yet .
# < i m not that desperate yet . <EOS>
#
# > vous etes l elue .
# = you are the one .
# < you the the one . <EOS>
#
# > je suis desolee si je t ai derange .
# = i am sorry if i disturbed you .
# < i m sorry if i disturbed you . <EOS>
#
# > j ai trop sommeil pour faire mes devoirs .
# = i m too sleepy to do my homework .
# < i m too sleepy to do my homework . <EOS>
#
# > nous sommes bourres .
# = we re smashed .
# < we re plastered . <EOS>
#
# > j en ai assez de faire semblant .
# = i m tired of pretending .
# < i m tired of pretending . <EOS>
#
# > c est un employe subalterne .
# = he s a junior employee .
# < he s a famous thinker . <EOS>
#
# > nous n en avons pas termine .
# = we re not done .
# < we re not finished . <EOS>
#
# Iter: 38
# Learning Rate: 1
# Time: 11h 33m 40s
# Train Loss: 0.16883705354291717
#
# > je suis desole mais tu dois partir .
# = i m sorry but you need to leave .
# < i m sorry but you need to leave . <EOS>
#
# > je suis pret pour une pause .
# = i m ready for a break .
# < i m ready for a break . <EOS>
#
# > tu es une veritable amie .
# = you re a true friend .
# < you re a wonderful friend . <EOS>
#
# > ils sont tres compatibles .
# = they are very compatible .
# < they are very big . <EOS>
#
# > tu ne pretes meme pas attention .
# = you re not even paying attention .
# < you re not even paying attention . <EOS>
#
# > vous etes vraiment geniales .
# = you re really awesome .
# < you re really beautiful . <EOS>
#
# > vous etes avide .
# = you re greedy .
# < you re greedy . <EOS>
#
# > elle passa toute l apres midi a cuisiner .
# = she spent all afternoon cooking .
# < she spent all afternoon cooking . <EOS>
#
# > tu es le professeur .
# = you re the teacher .
# < you re the teacher . <EOS>
#
# > tu t approches .
# = you re getting closer .
# < you re getting yourself . <EOS>
#
# Iter: 39
# Learning Rate: 1
# Time: 11h 58m 13s
# Train Loss: 0.1602396475686593
#
# > c est une puissante sorciere .
# = she s a powerful witch .
# < she s a powerful willed willed <EOS>
#
# > j appelle de mon telephone cellulaire .
# = i m calling from my cell phone .
# < i m calling from my cellphone now . <EOS>
#
# > nous en avons fini .
# = we re done .
# < we re finished . <EOS>
#
# > vous etes insupportable .
# = you are impossible .
# < you re the pathetic . <EOS>
#
# > vous etes nouveau ici n est ce pas ?
# = you re new here aren t you ?
# < you re new here aren t you ? <EOS>
#
# > nous sommes normales .
# = we re normal .
# < we re normal . <EOS>
#
# > vous etes fort avises .
# = you re very wise .
# < you re very wise . <EOS>
#
# > c est un jeune homme intelligent .
# = he s an intelligent young man .
# < he s an intelligent young man . <EOS>
#
# > tu n es pas japonaise .
# = you are not japanese .
# < you are not japanese . <EOS>
#
# > je ne suis pas etroit d esprit .
# = i m not narrow minded .
# < i m not narrow minded . <EOS>
#
# Iter: 40
# Learning Rate: 1
# Time: 12h 21m 59s
# Train Loss: 0.15034414271044744
#
# > nous n en sommes pas entierement surs .
# = we re not entirely sure .
# < we re not entirely sure . <EOS>
#
# > il a l esprit vif .
# = he is sharp witted .
# < he s open minded . <EOS>
#
# > je ne suis pas la pour me bagarrer .
# = i m not here to fight .
# < i m not here to fight . <EOS>
#
# > nous sommes impuissantes .
# = we re powerless .
# < we re lost . <EOS>
#
# > je suis juste un autre homme .
# = i m just another man .
# < i m just looking an man . <EOS>
#
# > vous etes garee en double file .
# = you re double parked .
# < you re double parked . <EOS>
#
# > tu n es pas le seul .
# = you re not the only one .
# < you re not the only one . <EOS>
#
# > je ne vais pas gaspiller mon argent .
# = i m not going to waste my money .
# < i m not going to waste my money . <EOS>
#
# > nous sommes susceptibles de commettre des erreurs .
# = we are apt to make mistakes .
# < we are apt to make mistakes . <EOS>
#
# > je suis responsable des courses .
# = i m in charge of shopping .
# < i m in charge of the risks . <EOS>
#
# Iter: 41
# Learning Rate: 1
# Time: 12h 45m 27s
# Train Loss: 0.14017795089794666
#
# > c est un mordu de cinema .
# = he s a movie buff .
# < he s a movie office . <EOS>
#
# > tu es fort timide .
# = you re very timid .
# < you re very shy . <EOS>
#
# > je suis suffisamment vieux .
# = i m old enough .
# < i m old enough . <EOS>
#
# > je fais mon devoir .
# = i m doing my duty .
# < i m doing my duty . <EOS>
#
# > tu ne comptes pas au nombre des suspects .
# = you re not a suspect .
# < you re not a suspect . <EOS>
#
# > nous sommes parfaitement en securite .
# = we re perfectly safe .
# < we re perfectly safe . <EOS>
#
# > c est un travailleur applique .
# = he is a hard worker .
# < he is a hard worker . <EOS>
#
# > tu es un type genial .
# = you re a wonderful guy .
# < you re a wonderful guy . <EOS>
#
# > ce n est pas une mauvaise fille .
# = she s not a bad girl .
# < she s not a bad girl . <EOS>
#
# > vous etes celle qui m a forme .
# = you re the one who trained me .
# < you re the one who trained me . <EOS>
#
# Iter: 42
# Learning Rate: 1
# Time: 13h 9m 42s
# Train Loss: 0.131392537238597
#
# > elle l a etouffe avec un oreiller .
# = she suffocated him with a pillow .
# < she suffocated him with a pillow . <EOS>
#
# > il a l habitude de realiser des discours .
# = he is used to making speeches .
# < he is used to making mistakes . <EOS>
#
# > je suis paume maintenant .
# = i m confused now .
# < i m confused now . <EOS>
#
# > je ne suis pas aux pieces .
# = i m not in a rush .
# < i m not in a rush . <EOS>
#
# > je commence a me sentir bete .
# = i m beginning to feel stupid .
# < i m starting to feel stupid . <EOS>
#
# > je crains la meme chose .
# = i m afraid of the same thing .
# < i m afraid the same thing . <EOS>
#
# > tu es son frere n est ce pas ?
# = you are his brother right ?
# < you are brother of his isn t ? <EOS>
#
# > nous n avons pas encore tres faim .
# = we aren t very hungry yet .
# < we aren t very hungry yet . <EOS>
#
# > tu es veinard .
# = you re in luck .
# < you re in luck . <EOS>
#
# > c est un expert du lancer de couteaux .
# = he s an expert at throwing knives .
# < he s an expert at throwing knives . <EOS>
#
# Iter: 43
# Learning Rate: 1
# Time: 13h 33m 52s
# Train Loss: 0.12308443576556582
#
# > je ne suis pas une enfant unique .
# = i m not an only child .
# < i m not an only child . <EOS>
#
# > je ne vais pas rentrer a la maison .
# = i m not coming back home .
# < i m not coming back home . <EOS>
#
# > elle est toujours occupee les jours de semaine .
# = she s always busy on weekdays .
# < she s always busy on weekdays . <EOS>
#
# > elle a ans .
# = she is thirty one .
# < she s got years one . <EOS>
#
# > je m entraine pour le triathlon .
# = i m training for the triathlon .
# < i m training for the triathlon . <EOS>
#
# > nous sommes piegees !
# = we re trapped !
# < we re stupid . <EOS>
#
# > enchante de faire votre connaissance .
# = i m pleased to meet you .
# < i m pleased to meet you . <EOS>
#
# > je suis contente de t aider .
# = i am glad to help you .
# < i am glad to help you . <EOS>
#
# > il n est vraiment pas heureux .
# = he is far from happy .
# < he is far but looking at . <EOS>
#
# > vous etes respecte de tous .
# = you re respected by everybody .
# < you re respected by everybody . <EOS>
#
# Iter: 44
# Learning Rate: 1
# Time: 13h 57m 58s
# Train Loss: 0.11449387611785274
#
# > ils sont surpris .
# = they re surprised .
# < they re surprised . <EOS>
#
# > il est maintenant a bord du bateau .
# = he s now aboard the ship .
# < he s now aboard the ship . <EOS>
#
# > vous etes tatillonne .
# = you re finicky .
# < you re kind . <EOS>
#
# > elles sont petites .
# = they re small .
# < they re kind of mine . <EOS>
#
# > nous sommes a court de biere .
# = we re out of beer .
# < we re out of beer . <EOS>
#
# > elles ne sont pas encore la .
# = they re not here yet .
# < they re not here yet . <EOS>
#
# > je suis professeur .
# = i m a teacher .
# < i a teacher teacher . <EOS>
#
# > j en ai fini avec vous .
# = i m done with you .
# < i m done with you . <EOS>
#
# > c est une jeune fille intelligente .
# = she s an intelligent young woman .
# < she s an intelligent young woman . <EOS>
#
# > vous etes pleines de ressources .
# = you re very resourceful .
# < you re very resourceful . <EOS>
#
# Iter: 45
# Learning Rate: 1
# Time: 14h 22m 57s
# Train Loss: 0.10846538157960854
#
# > vous etes tres raffinees .
# = you re very sophisticated .
# < you re very nice . <EOS>
#
# > elles s ennuient .
# = they are bored .
# < they re bored . <EOS>
#
# > je vais etre votre avocat .
# = i m going to be your lawyer .
# < i m going to be your lawyer . <EOS>
#
# > je vais passer a la television .
# = i m going to be on tv .
# < i m going to be on tv . <EOS>
#
# > vous etes tres solitaire .
# = you re very lonely .
# < you re very lonely . <EOS>
#
# > ce n est pas une beaute .
# = she is no beauty .
# < she is no beauty . <EOS>
#
# > elle n est pas a blamer .
# = she is not to blame .
# < she is not to blame . <EOS>
#
# > je ne suis pas malheureuse .
# = i m not miserable .
# < i m not miserable . <EOS>
#
# > je suis assez fier de cela .
# = i m pretty proud of that .
# < i m pretty proud of that . <EOS>
#
# > tu es riche n est ce pas ?
# = you re wealthy aren t you ?
# < you re wealthy aren t you ? <EOS>
#
# Iter: 46
# Learning Rate: 1
# Time: 14h 47m 43s
# Train Loss: 0.10255464602009026
#
# > ca ne m amuse pas .
# = i m not amused .
# < i am not amused . <EOS>
#
# > je ne vous blame pas .
# = i m not blaming you .
# < i m not buying you . <EOS>
#
# > vous etes fort avisees .
# = you re very wise .
# < you re very wise . <EOS>
#
# > vous etes bonnes .
# = you are good .
# < you re good . <EOS>
#
# > nous partirons demain .
# = we re leaving tomorrow .
# < we re leaving tomorrow . <EOS>
#
# > nous allons toutes a la maison .
# = we re all going home .
# < we re all going home . <EOS>
#
# > tu es une petite menteuse .
# = you re a little liar .
# < you re a little liar . <EOS>
#
# > je ne suis pas satisfait .
# = i m dissatisfied .
# < i m not satisfied . <EOS>
#
# > ca fait dix ans qu il est mort .
# = he s been dead ten years .
# < he s been dead ten years . <EOS>
#
# > tu es tres contrariee .
# = you re very upset .
# < you re very upset . <EOS>
#
# Iter: 47
# Learning Rate: 1
# Time: 15h 12m 23s
# Train Loss: 0.09702093828040942
#
# > je suis un etre mauvais .
# = i am a bad person .
# < i am a bad person . <EOS>
#
# > tu es tout seul .
# = you re all alone .
# < you re all alone . <EOS>
#
# > il est photogenique .
# = he is photogenic .
# < he s photogenic . <EOS>
#
# > je vais te proteger tom .
# = i m going to protect you tom .
# < i m going to protect you tom . <EOS>
#
# > c est vous qui m avez formee .
# = you re the one who trained me .
# < you re the one who trained me . <EOS>
#
# > je vais etre pret pour ca .
# = i m going to be ready for that .
# < i m going to be ready for that . <EOS>
#
# > je lis une lettre .
# = i am reading a letter .
# < i am reading a letter . <EOS>
#
# > je ne suis pas un expert .
# = i m not an expert .
# < i m not an expert . <EOS>
#
# > c est un nouveau venu .
# = he s a newcomer .
# < he s a newcomer . <EOS>
#
# > nous ne sommes pas en train de sourire .
# = we re not smiling .
# < we re not smiling . <EOS>
#
# Iter: 48
# Learning Rate: 1
# Time: 15h 36m 57s
# Train Loss: 0.09069363426005626
#
# > ils sont courageux .
# = they re brave .
# < they re brave . <EOS>
#
# > j ai peur de la hauteur .
# = i m scared of heights .
# < i m afraid of heights . <EOS>
#
# > il est toujours en train de rire .
# = he is always laughing .
# < he is always laughing . <EOS>
#
# > tu reussiras sans aucun doute quoique tu fasses .
# = you are sure to succeed whatever you do .
# < you are sure to succeed whatever you do . <EOS>
#
# > je suis tres heureuse .
# = i m very happy .
# < i m very happy happy . <EOS>
#
# > tu n es pas tres amusant .
# = you re not very funny .
# < you re not very funny . <EOS>
#
# > tu ne conviens pas .
# = you re not fit .
# < you re not fit . <EOS>
#
# > elle est tranquille .
# = she is quiet .
# < she is japanese . <EOS>
#
# > nous sommes tous deux ecrivains .
# = we re both writers .
# < we re both writers . <EOS>
#
# > je n attends personne .
# = i m not expecting anyone .
# < i m not expecting anyone . <EOS>
#
# Iter: 49
# Learning Rate: 1
# Time: 16h 1m 41s
# Train Loss: 0.0862068084869882
#
# > je suis presque pret .
# = i am almost ready .
# < i m about ready . <EOS>
#
# ...
#
# > il fait un super boulot .
# = he is doing a super job .
# < he is doing a super job . <EOS>
#
# > je ne suis pas normal .
# = i m not normal .
# < i m not normal . <EOS>
#
# Iter: 85
# Learning Rate: 1
# Time: 32h 5m 49s
# Train Loss: 0.0358260746208889
#
# > ils sont differents .
# = they re different .
# < they re different . <EOS>
#
# > ils jalousent notre succes .
# = they are jealous of our success .
# < they are jealous of our success . <EOS>
#
# > je songe a acheter un nouveau parasol .
# = i am thinking about buying a new parasol .
# < i am thinking about buying a new parasol . <EOS>
#
# > vous etes degoutante .
# = you re disgusting .
# < you re being disgusting . <EOS>
#
# > ils sont tous mauvais .
# = they re all bad .
# < they are all bad . <EOS>
#
# > nous sommes chez nous .
# = we re home .
# < we re home . <EOS>
#
# > je suis flasque .
# = i m flabby .
# < i m a boss . <EOS>
#
# > elle n est pas apte pour le poste .
# = she isn t fit for the job .
# < she isn t fit for the job . <EOS>
#
# > il a ete boire une biere .
# = he s been drinking beer .
# < he s been drinking beer . <EOS>
#
# > vous etes trop critique des defauts des autres .
# = you are too critical of others shortcomings .
# < you are too critical of others shortcomings . <EOS>
#
# Iter: 86
# Learning Rate: 1
# Time: 32h 33m 7s
# Train Loss: 0.0351871316258007
#
# > tu es impatiente .
# = you re impatient .
# < you re impatient . <EOS>
#
# > tu es timide .
# = you re shy .
# < you re shy . <EOS>
#
# > tu es tres occupe .
# = you re very busy .
# < you re very busy . <EOS>
#
# > elle est fauchee .
# = she is hard up for money .
# < she is hard up for money . <EOS>
#
# > je ne suis pas anglaise .
# = i m not english .
# < i m not english . <EOS>
#
# > elle est occupee a preparer le voyage .
# = she is busy preparing for the trip .
# < she is busy preparing for the trip . <EOS>
#
# > j essaie de te parler .
# = i m trying to talk to you .
# < i m trying to talk to you . <EOS>
#
# > vous etes tres droles .
# = you re very funny .
# < you are very funny . <EOS>
#
# > il n y va pas .
# = he s not going .
# < he s not going . <EOS>
#
# > elles sont de grandes amies .
# = they are great friends .
# < they are great friends . <EOS>
#
# Iter: 87
# Learning Rate: 1
# Time: 33h 1m 5s
# Train Loss: 0.035232397771807644
#
# > ils ne sont pas mauvais .
# = they re not evil .
# < they re not evil . <EOS>
#
# > vous avez tres sommeil non ?
# = you re feeling very sleepy aren t you ?
# < you re very sleepy aren t you ? <EOS>
#
# > j y travaille encore .
# = i m still working on it .
# < i m working on it . <EOS>
#
# > il est derriere moi .
# = he s after me .
# < he s after me . <EOS>
#
# > il est fort malade .
# = he s very ill .
# < he s very ill . <EOS>
#
# > elle est vraiment passionnee de tricot .
# = she is really into knitting .
# < she is really into knitting . <EOS>
#
# > je vais resoudre ca .
# = i m going to figure this out .
# < i m going to figure this out . <EOS>
#
# > ils sont tous dingues .
# = they re all nuts .
# < they re all nuts . <EOS>
#
# > elle plante des roses dans le jardin .
# = she s in the garden planting roses .
# < she s in the garden planting roses . <EOS>
#
# > nous ne plaisantons pas .
# = we re not kidding .
# < we re not getting any joking . <EOS>
#
# Iter: 88
# Learning Rate: 1
# Time: 33h 29m 22s
# Train Loss: 0.03555219465398429
#
# > il est trop lent .
# = he s too slow .
# < he s too slow . <EOS>
#
# > ils sont mauvais .
# = they re bad .
# < they re bad . <EOS>
#
# > il ne m a jamais frappe auparavant .
# = he s never hit me before .
# < he s never hit me before . <EOS>
#
# > vous etes tres vif .
# = you re very sharp .
# < you re very sharp . <EOS>
#
# > il n est pas mon pere .
# = he s not my father .
# < he s not my father . <EOS>
#
# > je suis fiere de mon pere .
# = i m proud of my dad .
# < i m proud of my father . <EOS>
#
# > je me fais vieux .
# = i m getting old .
# < i m getting old . <EOS>
#
# > je suis certain qu il est heureux .
# = i m sure that he s happy .
# < i m sure that he s happy . <EOS>
#
# > elle le vit conduire sa nouvelle voiture .
# = she saw him driving his new car .
# < she saw him driving his new car . <EOS>
#
# > je suis en vacances cette semaine .
# = i am on holiday this week .
# < i am on holiday this week . <EOS>
#
# Iter: 89
# Learning Rate: 1
# Time: 33h 57m 22s
# Train Loss: 0.03430749393464776
#
# > nous sommes tres en retard .
# = we re really late .
# < we re really late . <EOS>
#
# > tu n es plus un enfant .
# = you are not a child anymore .
# < you are not a child anymore . <EOS>
#
# > tu me fais peur .
# = you re scaring me .
# < you re scaring me . <EOS>
#
# > tu n es pas notre amie .
# = you are not our friend .
# < you are not our friend . <EOS>
#
# > c est mon vieux compagnon de beuverie .
# = he s my old drinking buddy .
# < he s my old drinking buddy . <EOS>
#
# > tu es plus grand que moi .
# = you re taller than i am .
# < you re taller than i am . <EOS>
#
# > je suis tres content de ma nouvelle voiture .
# = i am really pleased with my new car .
# < i m very happy with my new car . <EOS>
#
# > je suis assez heureuse .
# = i m pretty happy .
# < i m happy enough . <EOS>
#
# > elles agissent de leur propre chef .
# = they re acting on their own .
# < they re acting on their own . <EOS>
#
# > ils ont raison bien sur .
# = they re right of course .
# < they re right of course . <EOS>
#
# Iter: 90
# Learning Rate: 1
# Time: 34h 25m 57s
# Train Loss: 0.03413849898849947
#
# > vous devez faire comme je vous dis .
# = you are to do as i tell you .
# < you are to do as i tell you . <EOS>
#
# > je me rejouis de l avoir fait .
# = i m glad i did it .
# < i m glad i did it . <EOS>
#
# > nous sommes en danger .
# = we re in danger .
# < we re in danger . <EOS>
#
# > tu es tres grande .
# = you re very tall .
# < you re very tall . <EOS>
#
# > je ne suis plus inspiree .
# = i m not inspired anymore .
# < i m not inspired anymore . <EOS>
#
# > elle est en train de cuisiner pour lui .
# = she is cooking for him .
# < she is cooking for him . <EOS>
#
# > vous etes tres emotive .
# = you re very emotional .
# < you re very emotional . <EOS>
#
# > tu es tellement belle dans cette robe !
# = you re so beautiful in that dress .
# < you re so beautiful in that dress . <EOS>
#
# > je suis tres heureux d etre ici .
# = i m very happy to be here .
# < i m very happy to be here . <EOS>
#
# > je suis l une de vos eleves .
# = i m one of your students .
# < i m one of your students . <EOS>
#
# Iter: 91
# Learning Rate: 1
# Time: 34h 54m 37s
# Train Loss: 0.03372428395130018
#
# > c etaient des jeunes gens habituels .
# = they are typical young people .
# < they are typical young people . <EOS>
#
# > elle est tres attirante .
# = she s hot .
# < she s remarkably attractive . <EOS>
#
# > tu n es pas si interessant .
# = you re not that interesting .
# < you re not that interesting . <EOS>
#
# > elles se trouvent juste derriere vous .
# = they re right behind you .
# < they re right behind you . <EOS>
#
# > vous etes pardonnes .
# = you re forgiven .
# < you re forgiven . <EOS>
#
# > ils ne sont pas en train de suivre .
# = they re not following .
# < they re not following . <EOS>
#
# > vous allez aussi me manquer .
# = i m going to miss you too .
# < i m going to miss you too . <EOS>
#
# > nous manquons quelque chose ici .
# = we re missing something here .
# < we re missing something here . <EOS>
#
# > c est mon partenaire .
# = he s my partner .
# < he my my partner . <EOS>
#
# > vous etes sympa .
# = you re nice .
# < you re nice . <EOS>
#
# Iter: 92
# Learning Rate: 1
# Time: 35h 23m 20s
# Train Loss: 0.033896491854469586
#
# > elle aurait du etre plus prudente .
# = she should have been more careful .
# < she should have been more careful . <EOS>
#
# > nous sommes une grande famille .
# = we re a big family .
# < we re a big family . <EOS>
#
# > nous ne sommes pas des etrangers .
# = we re not strangers .
# < we re not strangers . <EOS>
#
# > je suis desolee de vous avoir blesses .
# = i m sorry i hurt you .
# < i m sorry i hurt you . <EOS>
#
# > tu es fort elegante .
# = you re very stylish .
# < you re very good too . <EOS>
#
# > ils sont mauvais .
# = they re bad .
# < they re bad . <EOS>
#
# > je garde ce siege pour tom .
# = i m saving this seat for tom .
# < i m saving this seat for tom . <EOS>
#
# > c est toi l enseignante .
# = you re the teacher .
# < you re the teacher . <EOS>
#
# > nous sommes quittes .
# = we re even .
# < we re even involved . <EOS>
#
# > il est americain .
# = he is an american .
# < he is a american . <EOS>
#
# Iter: 93
# Learning Rate: 1
# Time: 35h 51m 54s
# Train Loss: 0.03338643366691327
#
# > nous sommes perplexes .
# = we re baffled .
# < we re confused . <EOS>
#
# > elle le gifla .
# = she slapped him .
# < she slapped him . <EOS>
#
# > vous n etes pas tres ordonne .
# = you re not very tidy .
# < you re not very tidy . <EOS>
#
# > il est aristocrate .
# = he s an aristocrat .
# < he s an aristocrat . <EOS>
#
# > je suis vraiment desole .
# = i am very sorry .
# < i m very sorry . <EOS>
#
# > il est un peu ivre .
# = he s a bit drunk .
# < he s a bit drunk . <EOS>
#
# > je suis tout seul dans ce pays etranger .
# = i am all alone in a foreign country .
# < i am all alone in a foreign country . <EOS>
#
# > je suis en cours de concentration .
# = i m concentrating .
# < i m concentrating . <EOS>
#
# > elles sont medecins .
# = they re doctors .
# < they are doctors . <EOS>
#
# > c est un fumeur invetere .
# = he s a chain smoker .
# < s a a chain smoker . <EOS>
#
# Iter: 94
# Learning Rate: 1
# Time: 36h 20m 28s
# Train Loss: 0.03322558747583121
#
# > je crains que tu t egares .
# = i am afraid that you will get lost .
# < i am afraid that you will get lost . <EOS>
#
# > il est fiance a ma jeune s ur .
# = he is engaged to my younger sister .
# < he is engaged to my younger sister . <EOS>
#
# > nous aurons une nouvelle voiture le mois prochain .
# = we re getting a new car next month .
# < we re getting a new car next month . <EOS>
#
# > j en suis conscient .
# = i m aware of that .
# < i m aware of that . <EOS>
#
# > il est plus fort que toi .
# = he s stronger than you .
# < he s stronger than you . <EOS>
#
# > elle est son propre pire ennemi .
# = she is her own worst enemy .
# < she is her own worst enemy . <EOS>
#
# > il a honte de son echec .
# = he is ashamed of his failure .
# < he is ashamed of his failure . <EOS>
#
# > ici je suis un etranger .
# = i am a stranger here .
# < i am a foreigner . <EOS>
#
# > tu as toujours quelque chose a me reprocher .
# = you are always finding fault with me .
# < you are always finding fault with me . <EOS>
#
# > tu es bon .
# = you are good .
# < you re good . <EOS>
#
# Iter: 95
# Learning Rate: 1
# Time: 36h 49m 53s
# Train Loss: 0.032601377497766273
#
# > il est tres fier de sa moto trafiquee .
# = he s very proud of his custom motorcycle .
# < he s very proud of his custom motorcycle . <EOS>
#
# > nous sommes tellement fieres de vous !
# = we re so proud of you !
# < we re so proud of you ! <EOS>
#
# > vous etes rusees .
# = you re crafty .
# < you re very astute . <EOS>
#
# > il vous attend chez lui .
# = he s waiting for you at home .
# < he s waiting for you at home . <EOS>
#
# > je suis trop agee pour tom .
# = i m too old for tom .
# < i m too old for tom . <EOS>
#
# > je n ai pas peur de mourir .
# = i m not afraid to die .
# < i m not afraid to die . <EOS>
#
# > je suis cuisinier .
# = i am a cook .
# < i am a cook cook . <EOS>
#
# > toutes ces disputes commencent a me fatiguer .
# = i m growing tired of all this arguing .
# < i m growing tired of all this arguing . <EOS>
#
# > je ne suis pas du tout romantique .
# = i am not romantic at all .
# < i m not at all interested . <EOS>
#
# > elles parlent .
# = they re talking .
# < they re talking . <EOS>
#
# Iter: 96
# Learning Rate: 1
# Time: 37h 18m 53s
# Train Loss: 0.0337932898648027
#
# > nous sommes en securite .
# = we re safe .
# < we re safe . <EOS>
#
# > je me sens stressee .
# = i m feeling stressed .
# < i m feeling confused . <EOS>
#
# > nous sommes le probleme .
# = we re the problem .
# < we re the problem . <EOS>
#
# > j ai conge aujourd hui .
# = i am off duty today .
# < i am off duty today . <EOS>
#
# > je creve de faim !
# = i m starving .
# < i m very hungry . <EOS>
#
# > vous etes plus intelligente que moi .
# = you re smarter than me .
# < you re smarter than me . <EOS>
#
# > il commence a avoir les foies .
# = he s getting cold feet .
# < he s getting cold feet . <EOS>
#
# > je suis desolee je ne parle pas francais .
# = i m sorry i don t speak french .
# < i m sorry i don t speak french . <EOS>
#
# > elle a dit qu elle avait ete heureuse .
# = she said that she had been happy .
# < she said that she had been happy . <EOS>
#
# > il n est plus tout jeune .
# = he s not young anymore .
# < he s not young anymore . <EOS>
#
# Iter: 97
# Learning Rate: 1
# Time: 37h 47m 37s
# Train Loss: 0.03250243001660533
#
# > je ne m implique pas .
# = i m not getting involved .
# < i am not getting involved . <EOS>
#
# > j en ai marre d elle .
# = i m fed up with her .
# < i m fed up with her . <EOS>
#
# > tu es tout a fait attirant .
# = you re quite attractive .
# < you re quite attractive . <EOS>
#
# > je suis terrifiee .
# = i m terrified .
# < i m confused . <EOS>
#
# > j en ai fini avec vous .
# = i m done with you .
# < i m done with you . <EOS>
#
# > ils sont dans le laboratoire de sciences .
# = they re in the science lab .
# < they re in the science lab . <EOS>
#
# > vous n etes pas ainsi d ordinaire .
# = you re not usually like this .
# < you re not usually like this . <EOS>
#
# > vous n etes pas si interessants .
# = you re not that interesting .
# < you re not that interesting . <EOS>
#
# > c est un tel pauvre type !
# = he s such a jerk .
# < he s such a jerk . <EOS>
#
# > vous etes fiable .
# = you re trustworthy .
# < you re trustworthy . <EOS>
#
# Iter: 98
# Learning Rate: 1
# Time: 38h 16m 16s
# Train Loss: 0.03185378107361638
#
# > je suis plutot occupe .
# = i m pretty busy .
# < i m pretty busy . <EOS>
#
# > vous n etes jamais chez vous .
# = you re never at home .
# < you re never at home . <EOS>
#
# > je suis egalement occupee .
# = i m busy too .
# < i m busy busy . <EOS>
#
# > je suis respectueux .
# = i m observant .
# < i m very observant . <EOS>
#
# > tu es tellement paranoiaque !
# = you re so paranoid .
# < you re so paranoid . <EOS>
#
# > nous sommes en retard .
# = we re late .
# < we re late . <EOS>
#
# > elle est son propre pire ennemi .
# = she is her own worst enemy .
# < she is her own worst enemy . <EOS>
#
# > je suis financierement independant de mes parents .
# = i m economically independent of my parents .
# < i m economically independent of my parents . <EOS>
#
# > je suis vraiment occupe a l instant .
# = i m really busy right now .
# < i m really busy right now . <EOS>
#
# > je suis cuisinier .
# = i am a cook .
# < i am a cook . <EOS>
#
# Iter: 99
# Learning Rate: 1
# Time: 38h 44m 47s
# Train Loss: 0.031239349164877018
#
# > je suis de votre cote .
# = i m on your side .
# < i m by your side . <EOS>
#
# > vous etes surmenes .
# = you re overworked .
# < you re overworked . <EOS>
#
# > vous etes tout a fait attirant .
# = you re quite attractive .
# < you re quite attractive . <EOS>
#
# > je ne vais pas citer de noms .
# = i m not going to name names .
# < i m not going to name names . <EOS>
#
# > ils sont tous deux bons .
# = they are both good .
# < they are both good . <EOS>
#
# > je suis fatiguee de boston .
# = i m tired of boston .
# < i m tired of boston . <EOS>
#
# > je ne suis pas stupide a ce point !
# = i m not that stupid !
# < i m not that stupid ! <EOS>
#
# > je garde la maison .
# = i m housesitting .
# < i m housesitting . <EOS>
#
# > tu n es qu un enfant .
# = you re just a kid .
# < you re just a boy . <EOS>
#
# > elles sont dans la douche .
# = they re in the shower .
# < they re in the shower . <EOS>
#
# Iter: 100
# Learning Rate: 1
# Time: 39h 13m 4s
# Train Loss: 0.031868507844337625
#
# > nous n en sommes pas entierement surs .
# = we re not entirely sure .
# < we re not entirely sure . <EOS>
#
# > nous sommes tous avides de connaitre la verite .
# = we are all eager to know the truth .
# < we are all eager to know the truth . <EOS>
#
# > je suis entre deux postes .
# = i m between jobs .
# < i m between jobs jobs . <EOS>
#
# > vous n etes pas l un des notres .
# = you re aren t one of us .
# < you re aren t one of us . <EOS>
#
# > je suis gavee .
# = i m stuffed .
# < i m stuffed . <EOS>
#
# > je suis si heureux pour vous tom .
# = i m so happy for you tom .
# < i m so happy for you tom . <EOS>
#
# > nous sommes censes etre ensemble .
# = we re meant to be together .
# < we re meant to be together . <EOS>
#
# > je ne suis pas votre ami .
# = i m not your friend .
# < i m no friend of yours . <EOS>
#
# > j attends que le magasin ouvre .
# = i am waiting for the store to open .
# < i am waiting for the store to open . <EOS>
#
# > nous sommes encore vulnerables .
# = we re still vulnerable .
# < we re still vulnerable . <EOS>

# %%
import pickle

with open('encoder.pkl','wb') as enc:
    pickle.dump(encoder, enc)
    enc.close()
    
with open('decoder.pkl','wb') as dec:
    pickle.dump(decoder, dec)
    dec.close()

# %%
outside_sent = "I'm waiting for the store to open."
outside_sent = normalizeString(outside_sent)
evaluate(encoder, decoder, outside_sent, cutoff_length=10)
# Out:
# 'i am interested in all these afternoon . <EOS>'
